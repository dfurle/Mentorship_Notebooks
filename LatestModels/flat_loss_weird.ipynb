# %% [markdown]
# # Copy of Previous RNN

# %% [markdown]
# ### Reminders:
#
# Read up on some of these:
# - https://machinelearningmastery.com/stateful-stateless-lstm-time-series-forecasting-python/
# - https://fairyonice.github.io/Stateful-LSTM-model-training-in-Keras.html
# - https://github.com/keras-team/keras/issues/5714
# - https://machinelearningmastery.com/use-different-batch-sizes-training-predicting-python-keras/
#
# ###Shuffle Data!!!!!
#
# "An issue with LSTMs is that they can easily overfit training data, reducing their predictive skill."
# https://machinelearningmastery.com/use-dropout-lstm-networks-time-series-forecasting/

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## Do Basic Imports

# %%
import numpy as np
from tensorflow import keras
import tensorflow as tf
import pandas
from matplotlib import pyplot as plt
from math import isnan
from scipy.stats import norm

pandas.set_option('display.max_columns', None)
np.set_printoptions(suppress=True, precision=3)

# %% [markdown]
# ## Obtain data

# %%
# read data from drive
# csv_train = pandas.read_csv("drive/MyDrive/first_10k.csv")
# csv_train = pandas.read_csv("first_10k.csv")
csv_train = pandas.read_csv("FDC_tracks.csv") # n entries read how many
# csv_train = pandas.read_csv("drive/MyDrive/FDC_tracks.csv")
# unparsed_train = np.array(csv_train)

# %%
csv_train.head()
# Out:
#    event  q_over_pt       phi       tanl         D           z    cov_00  \
# 0     16  -4.805151 -1.959486   9.798482  0.297428   77.505120  0.021094
# 1     24  -5.880641  1.876485  19.786031 -0.006984   85.962514  0.067124
# 2     25 -13.532026  2.467270   1.919118 -5.848427  169.210964  0.056179
# 3     30  -2.509802 -1.784146   7.587641  0.106512  138.046577  0.001521
# 4      3 -17.129251  1.434362  26.422720 -0.117898   77.013978  0.822236
#
#      cov_01    cov_02    cov_03    cov_04    cov_10    cov_11        cov_12  \
# 0  0.000653 -0.027212 -0.006715 -0.224267  0.000653  0.000638 -7.817921e-06
# 1  0.002900 -0.004425  0.009347 -0.006453  0.002900  0.000160 -4.810567e-05
# 2 -0.000222 -0.009946 -0.025623  0.013079 -0.000222  0.000408  1.169699e-04
# 3  0.000101 -0.000085 -0.000516 -0.000281  0.000101  0.000011 -7.323695e-07
# 4  0.018098 -0.320665 -0.046536 -0.182233  0.018098  0.001255  1.798809e-04
#
#      cov_13    cov_14    cov_20        cov_21    cov_22    cov_23    cov_24  \
# 0 -0.005356  0.008031 -0.027212 -7.817921e-06  0.056340  0.004573  0.479709
# 1  0.000510  0.000568 -0.004425 -4.810567e-05  0.012966 -0.002011  0.058131
# 2  0.000880  0.000775 -0.009946  1.169699e-04  0.001869  0.004919 -0.002284
# 3 -0.000062  0.000023 -0.000085 -7.323695e-07  0.000255 -0.000005  0.001518
# 4 -0.002116  0.006441 -0.320665  1.798809e-04  0.502796  0.000735  0.531593
#
#      cov_30    cov_31    cov_32    cov_33    cov_34    cov_40    cov_41  \
# 0 -0.006715 -0.005356  0.004573  0.047946 -0.029896 -0.224267  0.008031
# 1  0.009347  0.000510 -0.002011  0.002078 -0.008247 -0.006453  0.000568
# 2 -0.025623  0.000880  0.004919  0.015793 -0.001017  0.013079  0.000775
# 3 -0.000516 -0.000062 -0.000005  0.000394 -0.000201 -0.000281  0.000023
# 4 -0.046536 -0.002116  0.000735  0.006366 -0.020129 -0.182233  0.006441
#
#      cov_42    cov_43    cov_44    invcov_00     invcov_01    invcov_02  \
# 0  0.479709 -0.029896  4.431396   143.933823   -584.752441    71.106430
# 1  0.058131 -0.008247  0.320724    84.121002  -2496.677246    19.896095
# 2 -0.002284 -0.001017  0.012008   351.342438   -363.585754  1708.699219
# 3  0.001518 -0.000201  0.011923  1789.508301 -22791.476562   499.759003
# 4  0.531593 -0.020129  2.105992     3.716887    -19.546400     2.372189
#
#      invcov_03  invcov_04     invcov_10      invcov_11    invcov_12  \
# 0   -51.758160   0.297455   -584.752441   31170.962891  -196.155960
# 1   293.896851  10.064490  -2496.677246  164808.906250  -354.495514
# 2    56.188641 -29.411634   -363.585754    4098.782715  4257.465332
# 3 -1221.779907   1.429652 -22791.476562  928416.000000 -2251.875000
# 4    20.326704  -0.023099    -19.546400    1916.763306   -14.920174
#
#        invcov_13    invcov_14    invcov_20    invcov_21     invcov_22  \
# 0    3392.620605   -41.964233    71.106430  -196.155960    354.598877
# 1  -34171.839844 -1156.479614    19.896095  -354.495514    442.491974
# 2   -2095.252930   764.023682  1708.699219  4257.465332  98017.921875
# 3  115594.632812   -73.356216   499.759003 -2251.875000  16813.527344
# 4     499.045380     0.982400     2.372189   -14.920174      4.271091
#
#       invcov_23     invcov_24    invcov_30      invcov_31     invcov_32  \
# 0    -67.524841    -34.887592   -51.758160    3392.620605    -67.524841
# 1    124.139870    -75.981712   293.896851  -34171.839844    124.139870
# 2 -27079.699219  14216.606445    56.188641   -2095.252930 -27079.699219
# 3   -576.370728  -2134.675537 -1221.779907  115594.632812   -576.370728
# 4      9.561720     -0.735817    20.326704     499.045380      9.561720
#
#       invcov_33    invcov_34  invcov_40    invcov_41     invcov_42  \
# 0    399.795197     1.238834   0.297455   -41.964233    -34.887592
# 1   8736.033203   268.551880  10.064490 -1156.479614    -75.981712
# 2   8424.915039 -4363.819336 -29.411634   764.023682  14216.606445
# 3  19122.812500   146.384872   1.429652   -73.356216  -2134.675537
# 4    477.990967     2.387653  -0.023099     0.982400     -0.735817
#
#      invcov_43    invcov_44      chisq  Ndof       rms  t_start_cntr  \
# 0     1.238834     4.101790  29.831556    31  0.000022           0.0
# 1   268.551880    26.045252  42.979855    31  0.000031           0.0
# 2 -4363.819336  2400.837891  35.032513    29  0.000071           0.0
# 3   146.384872   358.339996  38.809673    35  0.000002           0.0
# 4     2.387653     0.678388  91.965485    37  0.000002           0.0
#
#    t_start_cntr_valid      t_tof  t_tof_valid  t_bcal  t_bcal_valid  t_fcal  \
# 0                   0   9.210448            1     0.0             0     0.0
# 1                   0  -5.618344            1     0.0             0     0.0
# 2                   0   1.340809            1     0.0             0     0.0
# 3                   0  -9.004800            1     0.0             0     0.0
# 4                   0 -11.595993            1     0.0             0     0.0
#
#    t_fcal_valid     hit1_u     hit1_v  hit1_sinv  hit1_cosv  hit1_sinu  \
# 0             0  25.603266  25.363954   0.965743  -0.259501   0.965964
# 1             0  12.344487   8.975666   0.966029  -0.258435   0.965851
# 2             0   6.377105   9.717168   0.966029  -0.258435   0.965851
# 3             0 -19.029623  -6.864800   0.966029  -0.258435   0.965851
# 4             0   8.667939   5.329167   0.966029  -0.258435   0.965851
#
#    hit1_cosu     hit1_s   hit1_ds  hit1_wire  hit1_glayer      hit1_z  \
# 0   0.258676 -26.337843  0.018860         48           22  339.206113
# 1   0.259098 -11.047391  0.011369         42           24  343.409518
# 2   0.259098  -8.346766  0.010658         55           24  343.432556
# 3   0.259098  13.382012  0.011570         72           24  343.462682
# 4   0.259098  -7.256778  0.012524         42           24  343.409518
#
#     hit1_time   hit1_dE_amp     hit1_q     hit2_u     hit2_v  hit2_sinv  \
# 0  211.026062  2.659252e-09   1.128650  18.303051   6.621758   0.965816
# 1    8.064485  1.721369e-08   7.305898   3.117893  -3.357399   0.965760
# 2   19.819923  3.578516e-08  15.188075   9.259556   7.432361   0.965760
# 3   13.417019  1.501083e-08   6.370955  25.714386  25.452661   0.965743
# 4   97.581726  9.334869e-09   3.961941   0.800183  -4.109546   0.965760
#
#    hit2_cosv  hit2_sinu  hit2_cosu     hit2_s   hit2_ds  hit2_wire  \
# 0  -0.259230   0.965919   0.258843 -12.895368  0.012052         26
# 1  -0.259436   0.966199   0.257799   0.141232  0.012001         36
# 2  -0.259436   0.966199   0.257799  -8.615009  0.010977         45
# 3  -0.259501   0.965964   0.258676 -26.441307  0.011441         48
# 4  -0.259436   0.966199   0.257799   1.732782  0.015378         39
#
#    hit2_glayer      hit2_z   hit2_time   hit2_dE_amp     hit2_q     hit3_u  \
# 0           21  337.037161   23.257982  1.147952e-08   4.872180 -24.945432
# 1           23  341.294030   24.267323  1.177430e-08   4.997293  -8.748506
# 2           23  341.309314  106.031387  2.410825e-08  10.232115   2.844710
# 3           22  339.206113   82.401741  1.635203e-08   6.940193  18.167230
# 4           23  341.299124   71.853531  4.381419e-09   1.859579  -8.463169
#
#       hit3_v  hit3_sinv  hit3_cosv  hit3_sinu  hit3_cosu     hit3_s   hit3_ds  \
# 0 -24.688418   0.965985  -0.258600   0.965985   0.258600  25.643838  0.013551
# 1 -12.100996   0.965743  -0.259501   0.965964   0.258676  10.837436  0.011808
# 2  -1.566110   0.965743  -0.259501   0.965964   0.258676  -0.618639  0.010887
# 3   6.502841   0.965816  -0.259230   0.965919   0.258843 -12.763493  0.012679
# 4  -5.116501   0.965816  -0.259230   0.965919   0.258843   7.043029  0.013219
#
#    hit3_wire  hit3_glayer      hit3_z   hit3_time   hit3_dE_amp     hit3_q  \
# 0         49           19  332.722859   99.965675  6.635408e-09   2.816225
# 1         42           22  339.202000   84.398109  1.303359e-08   5.531766
# 2         40           22  339.200630   16.325516  2.656886e-08  11.276459
# 3         26           21  337.037161   55.853264  8.793474e-09   3.732160
# 4         55           21  336.985110  120.432205  7.318883e-09   3.106308
#
#       hit4_u     hit4_v  hit4_sinv  hit4_cosv  hit4_sinu  hit4_cosu  \
# 0 -15.501194  -4.879737   0.965702  -0.259651   0.966079   0.258246
# 1 -12.084059  -8.710942   0.965816  -0.259230   0.965919   0.258843
# 2  -5.117350  -6.946152   0.965816  -0.259230   0.965919   0.258843
# 3 -24.886373 -24.618049   0.965985  -0.258600   0.965985   0.258600
# 4  -0.843998   4.102125   0.965810  -0.259251   0.966080   0.258244
#
#       hit4_s   hit4_ds  hit4_wire  hit4_glayer      hit4_z   hit4_time  \
# 0  10.577032  0.012522       69.0         18.0  304.788180   40.584621
# 1  10.778194  0.010918       55.0         21.0  336.985110   26.965776
# 2   6.256154  0.011803       45.0         21.0  337.003058  134.851456
# 3  25.576844  0.010712       49.0         19.0  332.722859   30.811415
# 4  -1.715235  0.015556       58.0         20.0  334.841077  145.247223
#
#     hit4_dE_amp     hit4_q     hit5_u     hit5_v  hit5_sinv  hit5_cosv  \
# 0  9.342871e-09   3.965337   6.719334  16.670417   0.965838  -0.259148
# 1  2.565796e-08  10.889848  -3.137694   3.308786   0.965810  -0.259251
# 2  1.306734e-08   5.546090  -6.171845  -4.355187   0.965810  -0.259251
# 3  3.308418e-08  14.041716 -14.939244  -4.859043   0.965702  -0.259651
# 4  4.240551e-09   1.799791   7.795745   9.118759   0.965985  -0.258600
#
#    hit5_sinu  hit5_cosu     hit5_s   hit5_ds  hit5_wire  hit5_glayer  \
# 0   0.966178   0.257875 -12.080010  0.019661       68.0         17.0
# 1   0.966080   0.258244  -0.115787  0.013058       61.0         20.0
# 2   0.966080   0.258244   5.417191  0.011323       52.0         20.0
# 3   0.966079   0.258246  10.274663  0.011255       68.0         18.0
# 4   0.965985   0.258600  -8.802030  0.011848       51.0         19.0
#
#        hit5_z   hit5_time   hit5_dE_amp    hit5_q     hit6_u     hit6_v  \
# 0  302.648729  179.999512  2.438811e-09  1.035090  22.177931  21.387342
# 1  334.838250   14.844313  7.703928e-09  3.269731  10.231929   7.368667
# 2  334.846730  126.227249  1.780307e-08  7.556045  -1.363424   1.475508
# 3  304.788662   12.199866  1.876720e-08  7.965246   6.332620  15.863901
# 4  332.722127   98.281471  1.275232e-08  5.412390   6.895492   4.065909
#
#    hit6_sinv  hit6_cosv  hit6_sinu  hit6_cosu     hit6_s   hit6_ds  hit6_wire  \
# 0   0.965710  -0.259624   0.966063   0.258306 -22.553415  0.011438       47.0
# 1   0.965702  -0.259651   0.966079   0.258246  -9.103293  0.011747       43.0
# 2   0.965985  -0.258600   0.965985   0.258600  -0.104986  0.010731       54.0
# 3   0.965838  -0.259148   0.966178   0.257875 -11.462936  0.012118       67.0
# 4   0.965702  -0.259651   0.966079   0.258246  -5.666423  0.013445       43.0
#
#    hit6_glayer      hit6_z   hit6_time   hit6_dE_amp     hit6_q     hit7_u  \
# 0         16.0  300.484069  113.732185  1.638331e-08   6.953468  14.651194
# 1         18.0  304.800720   77.278549  1.348907e-08   5.725084   2.211027
# 2         19.0  332.721029  143.726120  3.221284e-08  13.671899  -9.705140
# 3         17.0  302.649744   46.961407  1.112301e-08   4.720869  20.588714
# 4         18.0  304.800720   85.953682  6.838906e-09   2.902595  -0.262800
#
#       hit7_v  hit7_sinv  hit7_cosv  hit7_sinu  hit7_cosu     hit7_s   hit7_ds  \
# 0   4.540016   0.965930  -0.258804   0.966069   0.258285  -9.937165  0.014197
# 1  -3.236589   0.965838  -0.259148   0.966178   0.257875   0.537576  0.010928
# 2  -8.941329   0.965702  -0.259651   0.966079   0.258246   9.665333  0.011660
# 3  20.336859   0.965710  -0.259624   0.966063   0.258306 -21.186241  0.014385
# 4  -4.135496   0.965838  -0.259148   0.966178   0.257875   2.285290  0.014378
#
#    hit7_wire  hit7_glayer      hit7_z   hit7_time   hit7_dE_amp     hit7_q  \
# 0       29.0         15.0  298.331870  124.329651  5.614239e-09   2.382817
# 1       38.0         17.0  302.679174   77.507042  2.539838e-08  10.779678
# 2       50.0         18.0  304.797344   85.506584  1.419677e-08   6.025448
# 3       48.0         16.0  300.483314  126.349251  5.373642e-09   2.280702
# 4       41.0         17.0  302.676130  103.837357  5.381913e-09   2.284212
#
#       hit8_u     hit8_v  hit8_sinv  hit8_cosv  hit8_sinu  hit8_cosu  \
# 0  -6.890500 -16.441669   0.965919  -0.258846   0.966158   0.257952
# 1  -8.104880 -10.439774   0.965710  -0.259624   0.966063   0.258306
# 2  -6.404817  -0.964781   0.965838  -0.259148   0.966178   0.257875
# 3  14.099892   4.527606   0.965930  -0.258804   0.966069   0.258285
# 4  -7.307767  -8.092942   0.965710  -0.259624   0.966063   0.258306
#
#       hit8_s   hit8_ds  hit8_wire  hit8_glayer      hit8_z   hit8_time  \
# 0  12.080818  0.011493       30.0         14.0  296.194871   28.836712
# 1   9.596309  0.011995       44.0         16.0  300.486337  143.096985
# 2   3.835088  0.011595       59.0         17.0  302.657863  170.910583
# 3  -9.645109  0.011844       30.0         15.0  298.331446   23.465767
# 4   7.970861  0.013335       47.0         16.0  300.484069  138.066132
#
#     hit8_dE_amp    hit8_q     hit9_u     hit9_v  hit9_sinv  hit9_cosv  \
# 0  1.577607e-08  6.695740 -21.491551 -20.698890   0.965675  -0.259753
# 1  1.180939e-08  5.012186  -9.934636  -7.088419   0.965930  -0.258804
# 2  1.476826e-08  6.268002  12.857863  11.037521   0.965930  -0.258804
# 3  1.277517e-08  5.422088  -6.292838 -15.340440   0.965919  -0.258846
# 4  7.065235e-09  2.998654  -6.672685  -3.816962   0.965930  -0.258804
#
#    hit9_sinu  hit9_cosu     hit9_s   hit9_ds  hit9_wire  hit9_glayer  \
# 0   0.965995   0.258562  21.870477  0.010871       50.0         13.0
# 1   0.966069   0.258285   8.814012  0.011724       54.0         15.0
# 2   0.966069   0.258285 -12.367738  0.011491       45.0         15.0
# 3   0.966158   0.257952  11.201960  0.011554       31.0         14.0
# 4   0.966069   0.258285   5.432334  0.012307       54.0         15.0
#
#        hit9_z  hit9_time   hit9_dE_amp     hit9_q    hit10_u    hit10_v  \
# 0  294.026852  38.606995  2.704812e-08  11.479865 -10.272005  -2.256284
# 1  298.321278  40.035255  1.366850e-08   5.801237  -2.228944   3.200641
# 2  298.325091  35.792446  1.580470e-08   6.707893   6.303788  -0.660989
# 3  296.195181  -1.058024  1.516559e-08   6.436637 -19.726773 -19.435892
# 4  298.321278  62.184078  1.021302e-08   4.334651   0.264950   4.151763
#
#    hit10_sinv  hit10_cosv  hit10_sinu  hit10_cosu    hit10_s  hit10_ds  \
# 0    0.966227   -0.257693    0.965994    0.258563   6.502286  0.012832
# 1    0.965919   -0.258846    0.966158    0.257952  -0.484921  0.012598
# 2    0.965919   -0.258846    0.966158    0.257952  -2.913668  0.011269
# 3    0.965675   -0.259753    0.965995    0.258562  20.302440  0.022801
# 4    0.965919   -0.258846    0.966158    0.257952  -2.269366  0.012073
#
#    hit10_wire  hit10_glayer     hit10_z  hit10_time  hit10_dE_amp   hit10_q  \
# 0        64.0          12.0  246.228435   99.414665  8.318255e-09  3.530466
# 1        59.0          14.0  296.203840    3.858530  9.070273e-09  3.849640
# 2        35.0          14.0  296.196418   21.257765  1.856602e-08  7.879862
# 3        49.0          13.0  294.026639  155.412796  1.840623e-09  0.781204
# 4        56.0          14.0  296.202912    6.377586  1.136413e-08  4.823208
#
#     hit11_u    hit11_v  hit11_sinv  hit11_cosv  hit11_sinu  hit11_cosu  \
# 0  6.405799  13.369375    0.965777   -0.259372    0.965818    0.259222
# 1  7.829832  10.114795    0.965675   -0.259753    0.965995    0.258562
# 2 -8.361659 -13.280392    0.965675   -0.259753    0.965995    0.258562
# 3 -8.802549  -2.257867    0.966227   -0.257693    0.965994    0.258563
# 4  7.121939   7.891068    0.965675   -0.259753    0.965995    0.258562
#
#      hit11_s  hit11_ds  hit11_wire  hit11_glayer     hit11_z  hit11_time  \
# 0 -10.252854  0.011074        62.0          11.0  244.027223   26.103256
# 1  -9.258864  0.011296        53.0          13.0  294.027490   46.018974
# 2  11.226057  0.011839        39.0          13.0  294.024514   38.627590
# 3   5.743888  0.014055        61.0          12.0  246.229932  148.619751
# 4  -7.743007  0.011257        50.0          13.0  294.026852   91.165977
#
#    hit11_dE_amp   hit11_q    hit12_u    hit12_v  hit12_sinv  hit12_cosv  \
# 0  2.194500e-08  9.313983  16.706048  15.423052    0.966059   -0.258322
# 1  1.818459e-08  7.717973   7.409430   5.075392    0.966227   -0.257693
# 2  1.280876e-08  5.436345  14.709915  22.218865    0.965777   -0.259372
# 3  5.810621e-09  2.466166   4.760214  10.712389    0.965777   -0.259372
# 4  1.875136e-08  7.958526   4.677809   2.345565    0.966227   -0.257693
#
#    hit12_sinu  hit12_cosu    hit12_s  hit12_ds  hit12_wire  hit12_glayer  \
# 0    0.966108    0.258137 -16.649878  0.011935        46.0          10.0
# 1    0.965994    0.258563  -6.433949  0.011473        44.0          12.0
# 2    0.965818    0.259222 -19.133312  0.013600        63.0          11.0
# 3    0.965818    0.259222  -8.025536  0.011184        60.0          11.0
# 4    0.965994    0.258563  -3.607438  0.015644        44.0          12.0
#
#       hit12_z  hit12_time  hit12_dE_amp   hit12_q    hit13_u    hit13_v  \
# 0  241.912731   83.431206  1.217904e-08  5.169076  10.121235   2.113869
# 1  246.238418   22.380390  1.599935e-08  6.790508   1.081166  -2.833394
# 2  244.025936  140.368225  6.544538e-09  2.777658  23.191047  17.750954
# 3  244.029797   19.787468  1.990591e-08  8.448542  13.570805  12.800789
# 4  246.238418  143.026489  4.174850e-09  1.771906  -0.929574  -3.805206
#
#    hit13_sinv  hit13_cosv  hit13_sinu  hit13_cosu    hit13_s  hit13_ds  \
# 0    0.966011   -0.258500    0.966066    0.258294  -6.309325  0.012284
# 1    0.965777   -0.259372    0.965818    0.259222   0.890393  0.016680
# 2    0.966059   -0.258322    0.966108    0.258137 -21.211798  0.011080
# 3    0.966059   -0.258322    0.966108    0.258137 -13.669966  0.011578
# 4    0.965777   -0.259372    0.965818    0.259222   2.434637  0.012174
#
#    hit13_wire  hit13_glayer     hit13_z  hit13_time  hit13_dE_amp   hit13_q  \
# 0        33.0           9.0  239.690209   80.232559  1.031633e-08  4.378495
# 1        41.0          11.0  244.054249  128.572540  3.527010e-09  1.496947
# 2        38.0          10.0  241.912699    6.625402  2.181380e-08  9.258297
# 3        47.0          10.0  241.912735   30.073677  1.492744e-08  6.335562
# 4        43.0          11.0  244.051675   16.100670  1.083757e-08  4.599723
#
#      hit14_u    hit14_v  hit14_sinv  hit14_cosv  hit14_sinu  hit14_cosu  \
# 0 -16.042491 -14.768866    0.965901   -0.258912    0.966071    0.258277
# 1  -5.914120  -7.676431    0.966059   -0.258322    0.966108    0.258137
# 2   6.504512  -5.630572    0.966011   -0.258500    0.966066    0.258294
# 3   8.678332   2.253143    0.966011   -0.258500    0.966066    0.258294
# 4  -5.760386  -6.048531    0.966059   -0.258322    0.966108    0.258137
#
#      hit14_s  hit14_ds  hit14_wire  hit14_glayer     hit14_z  hit14_time  \
# 0  15.965464  0.010833        51.0           7.0  235.395305   72.967171
# 1   7.012403  0.012250        45.0          10.0  241.912727   90.030121
# 2  -0.429893  0.011340        25.0           9.0  239.683660   23.521124
# 3  -5.634270  0.014125        36.0           9.0  239.692664  101.328743
# 4   6.090585  0.011790        48.0          10.0  241.912739   38.886745
#
#    hit14_dE_amp    hit14_q    hit15_u    hit15_v  hit15_sinv  hit15_cosv  \
# 0  2.828553e-08  12.005053  -6.094230  -0.633643    0.965841   -0.259135
# 1  1.047389e-08   4.445370  -1.174501   2.716523    0.965938   -0.258774
# 2  1.758175e-08   7.462115 -17.015251 -22.481503    0.965938   -0.258774
# 3  5.712357e-09   2.424461  -4.701169 -10.142867    0.965938   -0.258774
# 4  1.316018e-08   5.585494  -4.542145  -2.126049    0.966011   -0.258500
#
#    hit15_sinu  hit15_cosu    hit15_s  hit15_ds  hit15_wire  hit15_glayer  \
# 0    0.965973    0.258644   3.539007  0.011342        59.0           6.0
# 1    0.965831    0.259174  -0.805505  0.010835        56.0           8.0
# 2    0.965831    0.259174  20.442383  0.012363        38.0           8.0
# 3    0.965831    0.259174   7.680641  0.012157        38.0           8.0
# 4    0.966066    0.258294   3.476748  0.012281        53.0           9.0
#
#       hit15_z  hit15_time  hit15_dE_amp    hit15_q    hit16_u    hit16_v  \
# 0  187.679578   23.365648  1.755280e-08   7.449826  10.938773   9.638805
# 1  237.541064   -1.247328  2.821558e-08  11.975363   4.802888   2.740821
# 2  237.537576   95.705421  9.968970e-09   4.231068 -21.204734 -14.731975
# 3  237.537576   11.712685  1.092537e-08   4.636985 -12.766701 -11.982419
# 4  239.706580   96.757607  1.032926e-08   4.383983   0.837629   3.674956
#
#    hit16_sinv  hit16_cosv  hit16_sinu  hit16_cosu    hit16_s  hit16_ds  \
# 0    0.965870   -0.259026    0.966133    0.258043 -10.673414  0.011555
# 1    0.965841   -0.259135    0.965973    0.258644  -3.852348  0.013086
# 2    0.965901   -0.258912    0.966071    0.258277  18.621681  0.010990
# 3    0.965901   -0.258912    0.966071    0.258277  12.827305  0.011736
# 4    0.965938   -0.258774    0.965831    0.259174  -2.342826  0.011085
#
#    hit16_wire  hit16_glayer     hit16_z  hit16_time  hit16_dE_amp    hit16_q  \
# 0        46.0           4.0  183.322727   96.744446  1.515097e-08   6.430432
# 1        45.0           6.0  187.674626   47.266888  7.635467e-09   3.240674
# 2        61.0           7.0  235.389818  102.092400  2.380292e-08  10.102527
# 3        50.0           7.0  235.395853   52.248482  1.356854e-08   5.758812
# 4        54.0           8.0  237.540677   -0.238253  2.171561e-08   9.216621
#
#     hit17_u   hit17_v  hit17_sinv  hit17_cosv  hit17_sinu  hit17_cosu  \
# 0 -4.763182 -8.639115    0.965899   -0.258919    0.965824    0.259200
# 1  0.153152 -2.111595    0.965975   -0.258636    0.965603    0.260021
# 2  3.109621  1.854814    0.965975   -0.258636    0.965603    0.260021
# 3  2.611493  4.943784    0.965975   -0.258636    0.965603    0.260021
# 4  5.484111  5.854590    0.965901   -0.258912    0.966071    0.258277
#
#     hit17_s  hit17_ds  hit17_wire  hit17_glayer     hit17_z  hit17_time  \
# 0  6.990656  0.011439        41.0           2.0  179.009842   41.009434
# 1  1.004975  0.024099        44.0           5.0  185.432379  152.570694
# 2 -2.580473  0.018502        46.0           5.0  185.429793  149.427322
# 3 -3.926740  0.012543        53.0           5.0  185.420741  128.523743
# 4 -5.852225  0.011536        49.0           7.0  235.396402   -2.125386
#
#    hit17_dE_amp   hit17_q    hit18_u   hit18_v  hit18_sinv  hit18_cosv  \
# 0  1.637875e-08  6.951530 -10.295968 -8.995537    0.965804   -0.259271
# 1  1.671128e-09  0.709267  -4.084655 -4.741435    0.965870   -0.259026
# 2  2.771237e-09  1.176179        NaN       NaN         NaN         NaN
# 3  9.263501e-09  3.931651   5.723347  5.462194    0.965870   -0.259026
# 4  1.533746e-08  6.509583  -1.070725 -2.887224    0.965975   -0.258636
#
#    hit18_sinu  hit18_cosu    hit18_s  hit18_ds  hit18_wire  hit18_glayer  \
# 0    0.965742    0.259503  10.038018  0.011153        51.0           1.0
# 1    0.966133    0.258043   4.546474  0.012100        47.0           4.0
# 2         NaN         NaN        NaN       NaN         NaN           NaN
# 3    0.966133    0.258043  -5.811102  0.012165        48.0           4.0
# 4    0.965603    0.260021   2.039523  0.011233        45.0           5.0
#
#       hit18_z  hit18_time  hit18_dE_amp   hit18_q   hit19_u   hit19_v  \
# 0  176.894811  151.456299  2.043227e-08  8.671942       NaN       NaN
# 1  183.322572   32.141903  1.121793e-08  4.761156 -4.528333 -2.718599
# 2         NaN         NaN           NaN       NaN       NaN       NaN
# 3  183.322417   70.682739  1.088371e-08  4.619308  3.614194  0.774678
# 4  185.431086   -7.872138  1.910483e-08  8.108546 -4.233690 -3.827737
#
#    hit19_sinv  hit19_cosv  hit19_sinu  hit19_cosu   hit19_s  hit19_ds  \
# 0         NaN         NaN         NaN         NaN       NaN       NaN
# 1     0.96579   -0.259326    0.965792    0.259320  3.766397  0.014416
# 2         NaN         NaN         NaN         NaN       NaN       NaN
# 3     0.96579   -0.259326    0.965792    0.259320 -2.257609  0.011815
# 4     0.96587   -0.259026    0.966133    0.258043  4.151731  0.013050
#
#    hit19_wire  hit19_glayer     hit19_z  hit19_time  hit19_dE_amp   hit19_q  \
# 0         NaN           NaN         NaN         NaN           NaN       NaN
# 1        52.0           3.0  181.183990  155.109436  5.335831e-09  2.264654
# 2         NaN           NaN         NaN         NaN           NaN       NaN
# 3        43.0           3.0  181.182496   66.311623  1.298494e-08  5.511120
# 4        49.0           4.0  183.322262  130.518280  7.725045e-09  3.278693
#
#     hit20_u   hit20_v  hit20_sinv  hit20_cosv  hit20_sinu  hit20_cosu  \
# 0       NaN       NaN         NaN         NaN         NaN         NaN
# 1 -0.383962  2.014778    0.965899   -0.258919    0.965824     0.25920
# 2       NaN       NaN         NaN         NaN         NaN         NaN
# 3 -1.891547 -4.215762    0.965899   -0.258919    0.965824     0.25920
# 4 -2.691006 -0.878514    0.965790   -0.259326    0.965792     0.25932
#
#     hit20_s  hit20_ds  hit20_wire  hit20_glayer     hit20_z  hit20_time  \
# 0       NaN       NaN         NaN           NaN         NaN         NaN
# 1 -0.793337  0.012466        53.0           2.0  179.024148    5.492600
# 2       NaN       NaN         NaN           NaN         NaN         NaN
# 3  3.213805  0.011296        44.0           2.0  179.013419   55.020321
# 4  1.862562  0.011128        52.0           3.0  181.183990   -3.242654
#
#    hit20_dE_amp   hit20_q   hit21_u   hit21_v  hit21_sinv  hit21_cosv  \
# 0           NaN       NaN       NaN       NaN         NaN         NaN
# 1  9.552751e-09  4.054415  3.758106  4.755731    0.965804   -0.259271
# 2           NaN       NaN       NaN       NaN         NaN         NaN
# 3  1.818437e-08  7.717879       NaN       NaN         NaN         NaN
# 4  2.089540e-08  8.868505  3.820785  3.574673    0.965804   -0.259271
#
#    hit21_sinu  hit21_cosu   hit21_s  hit21_ds  hit21_wire  hit21_glayer  \
# 0         NaN         NaN       NaN       NaN         NaN           NaN
# 1    0.965742    0.259503 -4.357289  0.012503        50.0           1.0
# 2         NaN         NaN       NaN       NaN         NaN           NaN
# 3         NaN         NaN       NaN       NaN         NaN           NaN
# 4    0.965742    0.259503 -3.777994  0.014038        48.0           1.0
#
#       hit21_z  hit21_time  hit21_dE_amp   hit21_q  hit22_u  hit22_v  \
# 0         NaN         NaN           NaN       NaN      NaN      NaN
# 1  176.895473   -2.235170  9.414221e-09  3.995620      NaN      NaN
# 2         NaN         NaN           NaN       NaN      NaN      NaN
# 3         NaN         NaN           NaN       NaN      NaN      NaN
# 4  176.896797  105.641121  5.835576e-09  2.476758      NaN      NaN
#
#    hit22_sinv  hit22_cosv  hit22_sinu  hit22_cosu  hit22_s  hit22_ds  \
# 0         NaN         NaN         NaN         NaN      NaN       NaN
# 1         NaN         NaN         NaN         NaN      NaN       NaN
# 2         NaN         NaN         NaN         NaN      NaN       NaN
# 3         NaN         NaN         NaN         NaN      NaN       NaN
# 4         NaN         NaN         NaN         NaN      NaN       NaN
#
#    hit22_wire  hit22_glayer  hit22_z  hit22_time  hit22_dE_amp  hit22_q  \
# 0         NaN           NaN      NaN         NaN           NaN      NaN
# 1         NaN           NaN      NaN         NaN           NaN      NaN
# 2         NaN           NaN      NaN         NaN           NaN      NaN
# 3         NaN           NaN      NaN         NaN           NaN      NaN
# 4         NaN           NaN      NaN         NaN           NaN      NaN
#
#    hit23_u  hit23_v  hit23_sinv  hit23_cosv  hit23_sinu  hit23_cosu  hit23_s  \
# 0      NaN      NaN         NaN         NaN         NaN         NaN      NaN
# 1      NaN      NaN         NaN         NaN         NaN         NaN      NaN
# 2      NaN      NaN         NaN         NaN         NaN         NaN      NaN
# 3      NaN      NaN         NaN         NaN         NaN         NaN      NaN
# 4      NaN      NaN         NaN         NaN         NaN         NaN      NaN
#
#    hit23_ds  hit23_wire  hit23_glayer  hit23_z  hit23_time  hit23_dE_amp  \
# 0       NaN         NaN           NaN      NaN         NaN           NaN
# 1       NaN         NaN           NaN      NaN         NaN           NaN
# 2       NaN         NaN           NaN      NaN         NaN           NaN
# 3       NaN         NaN           NaN      NaN         NaN           NaN
# 4       NaN         NaN           NaN      NaN         NaN           NaN
#
#    hit23_q  hit24_u  hit24_v  hit24_sinv  hit24_cosv  hit24_sinu  hit24_cosu  \
# 0      NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 1      NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 2      NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 3      NaN      NaN      NaN         NaN         NaN         NaN         NaN
# 4      NaN      NaN      NaN         NaN         NaN         NaN         NaN
#
#    hit24_s  hit24_ds  hit24_wire  hit24_glayer  hit24_z  hit24_time  \
# 0      NaN       NaN         NaN           NaN      NaN         NaN
# 1      NaN       NaN         NaN           NaN      NaN         NaN
# 2      NaN       NaN         NaN           NaN      NaN         NaN
# 3      NaN       NaN         NaN           NaN      NaN         NaN
# 4      NaN       NaN         NaN           NaN      NaN         NaN
#
#    hit24_dE_amp  hit24_q
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN

# %%
csv_train = csv_train[csv_train.columns.drop(list(csv_train.filter(regex=("sin"))))]
csv_train = csv_train[csv_train.columns.drop(list(csv_train.filter(regex=("cos"))))]

csv_train = csv_train[csv_train["rms"] < 0.1]
csv_train = csv_train[csv_train["t_tof_valid"] == 1]
csv_train = csv_train[csv_train["tanl"] < 100]
csv_train = csv_train[csv_train["chisq"]/csv_train["Ndof"] < 5]

# %%
len(csv_train)
# Out:
# 245045

# %%
unparsed_train = np.array(csv_train)

# %% [markdown]
# ## Ragged Custom Loss

# %%
csv_param = []
TOF_param = []

_min = []
_max = []
_TOF_min = []
_TOF_max = []

for s in ["_u", "_v", "hit.*_s", "_ds", "_wire", "_glayer", "_z", "_time", "_dE_amp", "_q"]:
    tmp = csv_train.filter(regex=(s)).stack().reset_index()[0]
    _min.append(min(tmp))
    _max.append(max(tmp))
    
# for s in ["t_start_cntr", "t_tof", "t_bcal", "t_fcal"]:
for s in ["t_tof"]:
    tmp = csv_train.filter(regex=(s)).stack().reset_index()[0]
    _TOF_min.append(min(tmp))
    _TOF_max.append(max(tmp))

print(_min)
print(_max)

print(_TOF_min)
print(_TOF_max)
# Out:
# [-47.77566409720066, -47.826128454115775, -47.970923331835934, 0.0100464087262316, 1.0, 1.0, 176.86502273229647, -77.795654296875, 7.068405941829982e-10, 0.2999999999999999]
# [47.76664529344056, 47.80431509217056, 47.9992377193164, 0.0433333333333333, 96.0, 24.0, 343.50521373311966, 276.1418151855469, 5.076923038534499e-07, 215.47671767788012]
# [-121.16037940160004]
# [186.5701039032152]

# %%
# attempt at using dataframes
# glob_index = 2
# def ragged_csv_parser(unparsed):
#     global _min, _max, glob_index, _TOF_min, _TOF_max
#     x_final = []
#     y_final = []
#     invCov_final = np.array(unparsed.filter(regex=("invcov_")))
#     cov_final = np.array(unparsed.filter(regex=("cov_")).iloc[:,:25])
    
#     for index, event in unparsed.iterrows():
#         hits = event.filter(regex=("hit"))
#         x_event = []
#         for hit in range(1,25):
#             vals = list(hits.filter(regex=("hit"+str(hit)+"_")))
#             if(not isnan(vals[0])):
#                 x_event.append(vals)
#         x_final.append(x_event)
#         y_final.append(np.array(event.loc["q_over_pt":"z"]))
# #         print("currently at:", index)
# #     x_ragged = x_final
#     x_ragged = tf.ragged.constant(x_final)
#     return [x_ragged, invCov_final, cov_final, y_final], y_final

# %%
# # split = 450000
# # split = 3
# # split = int(unparsed_train.shape[0]-1000)
# # np.random.shuffle(unparsed_train)
# csv_shuffle = csv_train.sample(frac=1).reset_index()
# print("shuffled")
# # split = int(csv_shuffle.shape[0]*0.80)
# split = 10
# x_train, y_train = ragged_csv_parser(csv_shuffle[:split]) # shuffle data before taking
# print("parsed train")
# x_test, y_test = ragged_csv_parser(csv_shuffle[split:])
# print("parsed test")
# # x_train, y_train = ragged_parser(unparsed_train[:split])
# # x_test , y_test  = ragged_parser(unparsed_train[split:split+100])

# print("--==Types==--")
# print("--x_train:--")
# print("\n  -> input_data: x_train[0]\n  -> type expected: RaggedTensor\n "+str(type(x_train[0])))
# print("\n  -> invCov: x_train[1]\n  -> type expected: np.array\n "+str(type(x_train[1])))
# print("\n  -> y_train: x_train[2]\n  -> type expected: np.array\n "+str(type(x_train[2])))
# print("\n--y_train:--")
# print("\n  -> y_train: y_train\n  -> type expected: np.array\n "+str(type(y_train)))

# print("\n\n--==Shapes==--")
# print("--x_train:--  \nnum of events: " + str(x_train[0].shape[0]))
# print("\n  RaggedTensor | Input:  shape = " + "(" + str(x_train[0].shape[0]) + ", "+ str(x_train[0][0].shape[0]) + ", "+ str(x_train[0][0][0].shape[0]) + ")")
# print("  np.array     | InvCov: shape = " + str(x_train[1].shape))
# print("  np.array     | Labels: shape = " + str(x_train[2].shape))
# print("\n--x_train:--")
# print("  np.array     | Labels: shape = " + str(y_train.shape))

# print("x_train : " + str(x_train[0][0]))
# print("y_train : " + str(y_train[0]))

# %% [markdown]
# After trying out many different possibilities, I have found making a RaggedTensor is the way to make variable timesteps.
#
# Once you create a RaggedTensor ONLY FOR X DATA, you need to also add:
#
# ragged=True
#
# to the keras.Inputs() function

# %%
glob_index = 2
def ragged_parser(unparsed):
  global _min, _max, glob_index
  x_final = []
  y_final = []
  invCov_final = []
  cov_final = []
  for event in unparsed:
    x = []
    y = []

    nEvent = event[0]     # all the data split into neat little arrays...
    state = event[1:6]
    coVar = event[6:31]
    invCoVar = event[31:56]
    goodnessOfFit = event[56:59]
    TOF = event[59:67]

#     if goodnessOfFit[0]/float(goodnessOfFit[1]) > 5:
#       continue
#     if goodnessOfFit[2] > 0.1:   # Cutting if rms is too high
#       continue
    hits = []
    lower = 67
    for upper in range(lower+14, event.shape[0]+1, 14): # to flip just go from end to 67 by -14 steps?

      # hasNAN = False
      # for val in event[lower:upper]:
      #   if isnan(val):
      #     hasNAN = True
      # if not hasNAN:

      if not isnan(event[lower]):            # Check if we are done with hits, because data is cut short, the rest will be nan
        hit_data = event[lower:upper]                      # retrieving the hit
        hit_data = np.append(hit_data[:2],hit_data[6:])    # cutting out the sin and cos data
        for z in range(len(hit_data)):
          hit_data[z] = (hit_data[z] - _min[z]) / (_max[z] - _min[z])    # we need to normalize the data; this can be moved to a lambda layer in the network if needed.
#         for i_TOF in range(4):
#           TOF[i_TOF*2] = (TOF[i_TOF*2] - _TOF_min[i_TOF]) / (_TOF_max[i_TOF] - _TOF_min[i_TOF])
        TOF_DATA = (TOF[2] - _TOF_min[2]) / (_TOF_max[2] - _TOF_min[2])
        hit_data = np.append(hit_data,TOF_DATA)
        hits.append(np.ndarray.tolist(hit_data))       # we want it as a list to convert to RaggedTensor later; last time I checked it didnt work with array.
      lower = upper
    for i in range(len(hits)):   # this could be simplified to just: "x = hits" if im not mistaken...
      x.append(hits[i])          # however we might need to add y.append(hits[i+1]) for later testing so leaving it like this for now...
    y = np.ndarray.tolist(state)   # technically not needed, can be removed later... at first I thought i need to pass RaggedTensor labels, but that is not the case.
    x_final.append(x)          # want x_final to be shape (event, hit, 10) as a list
#     y_final.append(y)          # want y_final to be shape (event, 5)       as a np.array
    y_final.append(y[glob_index])          # want y_final to be shape (event, 5)       as a np.array
    invCov_final.append(invCoVar[:])  # want other_f to be shape (event, 25)      as a np.array
    cov_final.append(coVar[:])
  x_final = tf.ragged.constant(x_final)   # convert list to RaggedTensor because timesteps (number of hits) are variable between events
  y_final = np.array(y_final)
  invCov_final = np.array(invCov_final)
  cov_final = np.array(cov_final)
  y_final = np.expand_dims(y_final,1)
  return [x_final, invCov_final, cov_final, y_final], y_final   # with the custom loss the x_train (input) needs to be a list of [inputs, inverseCovariance, labels]
  # return [x_final, invCov_final], y_final   # with the custom loss the x_train (input) needs to be a list of [inputs, inverseCovariance, labels]

# %%
glob_index = 2
def ragged_parser(unparsed):
  global _min, _max, glob_index
  x_final = []
  y_final = []
  invCov_final = []
  cov_final = []
  for event in unparsed:
    x = []
    y = []

    nEvent = event[0]
    state = event[1:6]
    coVar = event[6:31]
    invCoVar = event[31:56]
    goodnessOfFit = event[56:59]
    TOF = event[59:67]

    hits = []
    lower = 67
    for upper in range(lower+10, event.shape[0]+1, 10): # to flip just go from end to 67 by -14 steps?
      if not isnan(event[lower]):            # Check if we are done with hits, because data is cut short, the rest will be nan
        hit_data = event[lower:upper]        # retrieving the hit
        for z in range(len(hit_data)):
          hit_data[z] = (hit_data[z] - _min[z]) / (_max[z] - _min[z])    # we need to normalize the data; this can be moved to a lambda layer in the network if needed.
#         for i_TOF in range(4):
#           TOF[i_TOF*2] = (TOF[i_TOF*2] - _TOF_min[i_TOF]) / (_TOF_max[i_TOF] - _TOF_min[i_TOF])
#         TOF_DATA = (TOF[2] - _TOF_min[2]) / (_TOF_max[2] - _TOF_min[2])
        TOF_DATA = (TOF[2] - _TOF_min[0]) / (_TOF_max[0] - _TOF_min[0])
        hit_data = np.append(hit_data,TOF_DATA)
        hits.append(np.ndarray.tolist(hit_data))       # we want it as a list to convert to RaggedTensor later; last time I checked it didnt work with array.
      lower = upper
    for i in range(len(hits)):   # this could be simplified to just: "x = hits" if im not mistaken...
      x.append(hits[i])          # however we might need to add y.append(hits[i+1]) for later testing so leaving it like this for now...
    y = np.ndarray.tolist(state)   # technically not needed, can be removed later... at first I thought i need to pass RaggedTensor labels, but that is not the case.
    x_final.append(x)          # want x_final to be shape (event, hit, 10) as a list
#     y_final.append(y)          # want y_final to be shape (event, 5)       as a np.array
    y_final.append(y[glob_index])          # want y_final to be shape (event, 5)       as a np.array
    invCov_final.append(invCoVar[:])  # want other_f to be shape (event, 25)      as a np.array
    cov_final.append(coVar[:])
  x_final = tf.ragged.constant(x_final)   # convert list to RaggedTensor because timesteps (number of hits) are variable between events
  y_final = np.array(y_final)
  invCov_final = np.array(invCov_final)
  cov_final = np.array(cov_final)
  y_final = np.expand_dims(y_final,1)
  return [x_final, invCov_final, cov_final, y_final], y_final   # with the custom loss the x_train (input) needs to be a list of [inputs, inverseCovariance, labels]
  # return [x_final, invCov_final], y_final   # with the custom loss the x_train (input) needs to be a list of [inputs, inverseCovariance, labels]

# %%
np.random.shuffle(unparsed_train)
print("shuffled")
split = int(unparsed_train.shape[0]*0.80)
# split = 5
x_train, y_train = ragged_parser(unparsed_train[:split]) # shuffle data before taking
print("parsed train")
x_test, y_test = ragged_parser(unparsed_train[split:])
print("parsed test")

print("--==Types==--")
print("--x_train:--")
print("\n  -> input_data: x_train[0]\n  -> type expected: RaggedTensor\n "+str(type(x_train[0])))
print("\n  -> invCov: x_train[1]\n  -> type expected: np.array\n "+str(type(x_train[1])))
print("\n  -> y_train: x_train[2]\n  -> type expected: np.array\n "+str(type(x_train[2])))
print("\n--y_train:--")
print("\n  -> y_train: y_train\n  -> type expected: np.array\n "+str(type(y_train)))

print("\n\n--==Shapes==--")
print("--x_train:--  \nnum of events: " + str(x_train[0].shape[0]))
print("\n  RaggedTensor | Input:  shape = " + "(" + str(x_train[0].shape[0]) + ", "+ str(x_train[0][0].shape[0]) + ", "+ str(x_train[0][0][0].shape[0]) + ")")
print("  np.array     | InvCov: shape = " + str(x_train[1].shape))
print("  np.array     | Labels: shape = " + str(x_train[2].shape))
print("\n--y_train:--")
print("  np.array     | Labels: shape = " + str(y_train.shape))

print("x_train : " + str(x_train[0][0]))
print("y_train : " + str(y_train[0]))
# Out:
# shuffled
# parsed train
# parsed test
# --==Types==--
# --x_train:--
#
#   -> input_data: x_train[0]
#   -> type expected: RaggedTensor
#  <class 'tensorflow.python.ops.ragged.ragged_tensor.RaggedTensor'>
#
#   -> invCov: x_train[1]
#   -> type expected: np.array
#  <class 'numpy.ndarray'>
#
#   -> y_train: x_train[2]
#   -> type expected: np.array
#  <class 'numpy.ndarray'>
#
# --y_train:--
#
#   -> y_train: y_train
#   -> type expected: np.array
#  <class 'numpy.ndarray'>
#
#
# --==Shapes==--
# --x_train:--
# num of events: 196036
#
#   RaggedTensor | Input:  shape = (196036, 21, 11)
#   np.array     | InvCov: shape = (196036, 25)
#   np.array     | Labels: shape = (196036, 25)
#
# --y_train:--
#   np.array     | Labels: shape = (196036, 1)
# x_train : <tf.RaggedTensor [[0.3891345262527466, 0.397410124540329, 0.6098350882530212, 0.05172201618552208, 0.5157894492149353, 1.0, 0.9995108246803284, 0.21459481120109558, 0.02489054948091507, 0.02489054948091507, 0.3494623303413391], [0.4336733818054199, 0.4870547652244568, 0.5411680340766907, 0.2925613224506378, 0.6000000238418579, 0.95652174949646, 0.9869549870491028, 0.5042583346366882, 0.0033553135581314564, 0.0033553135581314564, 0.3494623303413391], [0.5426225662231445, 0.5886417031288147, 0.43277043104171753, 0.06805791705846786, 0.5894736647605896, 0.9130434989929199, 0.9742383360862732, 0.32488155364990234, 0.018708089366555214, 0.018708089366555214, 0.3494623303413391], [0.608670175075531, 0.6004201173782349, 0.39225223660469055, 0.04168902337551117, 0.4842105209827423, 0.8695651888847351, 0.9609593152999878, 0.21011510491371155, 0.03101160377264023, 0.03101160377264023, 0.3494623303413391], [0.563380241394043, 0.512028694152832, 0.4606671929359436, 0.08192099630832672, 0.4000000059604645, 0.8260869383811951, 0.9481143355369568, 0.25416553020477295, 0.015363204292953014, 0.015363204292953014, 0.3494623303413391], [0.45894694328308105, 0.4131176769733429, 0.5654124617576599, 0.11603707075119019, 0.410526305437088, 0.782608687877655, 0.9353153705596924, 0.6327420473098755, 0.01049485057592392, 0.01049485057592392, 0.3494623303413391], [0.4053306579589844, 0.4136199355125427, 0.5934145450592041, 0.05695640295743942, 0.5157894492149353, 0.739130437374115, 0.7677158713340759, 0.6141514182090759, 0.02253265492618084, 0.02253265492618084, 0.3494623303413391], [0.44914206862449646, 0.4952393174171448, 0.528798520565033, 0.06701609492301941, 0.5894736647605896, 0.695652186870575, 0.7548891305923462, 0.4445766806602478, 0.019014224410057068, 0.019014224410057068, 0.3494623303413391], [0.549839973449707, 0.5037904381752014, 0.4723956286907196, 0.04688376188278198, 0.410526305437088, 0.5652173757553101, 0.716111421585083, 0.23408132791519165, 0.027524719014763832, 0.027524719014763832, 0.3494623303413391], [0.45596373081207275, 0.42078444361686707, 0.5637457370758057, 0.027767643332481384, 0.43157893419265747, 0.52173912525177, 0.7030724287033081, 0.19848886132240295, 0.04648159444332123, 0.04648159444332123, 0.3494623303413391], [0.4240005910396576, 0.43768906593322754, 0.5714799761772156, 0.062365125864744186, 0.5263158082962036, 0.47826087474823, 0.41628554463386536, 0.30550211668014526, 0.020502934232354164, 0.020502934232354164, 0.3494623303413391], [0.47063758969306946, 0.5049082636833191, 0.512373685836792, 0.3973246216773987, 0.5684210658073425, 0.43478259444236755, 0.40309128165245056, 0.6158987879753113, 0.002107379026710987, 0.002107379026710987, 0.3494623303413391], [0.5418180823326111, 0.5663385987281799, 0.44396132230758667, 0.04149213805794716, 0.5473684072494507, 0.3913043439388275, 0.3903484344482422, 0.21238191425800323, 0.031160375103354454, 0.031160375103354454, 0.3494623303413391], [0.5739575624465942, 0.5603669881820679, 0.4309506118297577, 0.05326559767127037, 0.4736842215061188, 0.3478260934352875, 0.37707486748695374, 0.3093923032283783, 0.024148274213075638, 0.024148274213075638, 0.3494623303413391], [0.5289069414138794, 0.4937281012535095, 0.4882282018661499, 0.06941398233175278, 0.43157893419265747, 0.30434781312942505, 0.36409780383110046, 0.3377666473388672, 0.018323102965950966, 0.018323102965950966, 0.3494623303413391], [0.4602892994880676, 0.43469151854515076, 0.5542387366294861, 0.0640936866402626, 0.4526315927505493, 0.260869562625885, 0.35126054286956787, 0.23324471712112427, 0.019924955442547798, 0.019924955442547798, 0.3494623303413391], [0.43982794880867004, 0.4537028968334198, 0.5553913116455078, 0.025706371292471886, 0.5263158082962036, 0.21739129722118378, 0.06488066166639328, 0.309455543756485, 0.05012303218245506, 0.05012303218245506, 0.3494623303413391], [0.4850541353225708, 0.5094967484474182, 0.5025803446769714, 0.03975728154182434, 0.5473684072494507, 0.17391304671764374, 0.051 ...
# y_train : [24.171]

# %%
# plt.hist(csv_train["cov_11"],range=[0,0.05],bins=50) # -3 to 3, even distrib
# plt.title("phi")
# plt.show()

# %%
# fig, ax = plt.subplots(3,1,figsize=(5,15))
# fig.subplots_adjust(hspace=0.35)

# ax[0].hist(np.sqrt(x_train[1][:,24]),range=[0,2],bins=25)
# ax[0].set_title("cov_44")

# ax[1].hist(np.sqrt(x_train[1][:,24]),range=[0,20],bins=25)
# ax[1].set_title("cov_44")

# ax[2].hist(np.sqrt(x_train[1][:,24]),range=[0,200],bins=25)
# ax[2].set_title("cov_44")
# # plt.show()

# np.mean(np.sqrt(x_train[1][:,24]))

# %% [markdown]
# # Model

# %% [markdown]
# ## Defining Models
#
# - model
#   - Very basic testing RNN model
#   - Output every timestep
#
# - model_timeless
#   - Very basic testing RNN model
#   - Output only at the end
#
# - RNNTime
#   - Advanced
#   - Time distributed, output every timestep
#
# - RNNTimeless
#   - Advanced
#   - Only output at final layer

# %%
def model(x):
  x = keras.layers.LSTM(64,activation="tanh", name='input_lstm1', return_sequences=True)(x)
  x = keras.layers.TimeDistributed(keras.layers.Dense(32, activation='relu'), name="TD1-Dense")(x)
  x = keras.layers.TimeDistributed(keras.layers.Dense(14, activation='linear'), name="output-Dense")(x)
  return x
def model_timeless(x):
  x = keras.layers.LSTM(64,activation="tanh", name='input_lstm1', return_sequences=False)(x)
  x = keras.layers.Dense(32, activation='relu', name="Dense1")(x)
  x = keras.layers.Dense(5, activation='relu', name="output-Dense")(x)
  return x

def RNNTime(x):
  x = keras.layers.LSTM(128,activation="tanh", name='input_lstm1', stateful=False, return_sequences=True)(x)
  x = keras.layers.LSTM(64,activation="tanh", name='lstm2', stateful=False, return_sequences=True)(x)
  x = keras.layers.LSTM(32,activation="tanh", name='lstm3', stateful=False, return_sequences=True)(x)
  x = keras.layers.TimeDistributed(keras.layers.Dense(32, activation='relu'), name="TD1-Dense")(x)
  x = keras.layers.TimeDistributed(keras.layers.Dense(5, activation='linear'), name="output-Dense")(x)
  return x

def RNNTimeless(x):
  x = keras.layers.LSTM(1024,activation="tanh", name='input_lstm1', stateful=False, return_sequences=True)(x)
  x = keras.layers.Dropout(0.1)(x)
  x = keras.layers.LSTM(512,activation="tanh", name='lstm2', stateful=False, return_sequences=True)(x)
  x = keras.layers.Dropout(0.1)(x)
  x = keras.layers.LSTM(256,activation="tanh", name='lstm3', stateful=False, return_sequences=False)(x)
  x = keras.layers.Dropout(0.1)(x)
    
  x = keras.layers.Dense(256, activation='tanh', name="Dense1")(x)
  x = keras.layers.Dropout(0.1)(x)
  x = keras.layers.Dense(128, activation='tanh', name="Dense2")(x)
  x = keras.layers.Dropout(0.1)(x)
  x = keras.layers.Dense(64, activation='linear', name="Dense3")(x) ## LBR
  x = keras.layers.Dropout(0.1)(x)
  x = keras.layers.Dense(32, activation='linear', name="Dense4")(x)
  x = keras.layers.Dense(1, activation='linear', name="output-Dense")(x)
  # x = keras.layers.Dense(5, activation='linear', name="output-Dense")(x)
  # x = keras.layers.lambda(# normalize)
  return x

# %% [markdown]
# ## Custom Loss

# %% [markdown]
# ### V1 Originial, unedited

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
#--------------------------------------------
# Define custom loss function 
def customLoss(y_true, y_pred, invcov):
  # print(type(y_true))    #<class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>

  batch_size = tf.shape(y_pred)[0]
  print('y_pred shape: ' + str(y_pred.shape) )  # y_pred shape is (batch, 5)
  print('y_true shape: ' + str(y_true.shape) )  # y_true shape is (batch, 5)
  print('invcov shape: ' + str(invcov.shape) )  # invcov shape is (batch, 25)
  
  y_pred = K.reshape(y_pred, (batch_size, 5,1)) # y_pred  shape is now (batch, 5,1)
  y_true = K.reshape(y_true, (batch_size, 5,1)) # y_state shape is now (batch, 5,1)
  invcov = K.reshape(invcov, (batch_size, 5,5)) # invcov  shape is now (batch, 5,5)
  
  # n.b. we must use tf.transpose here an not K.transpose since the latter does not allow perm argument
  invcov = tf.transpose(invcov, perm=[0,2,1])     # invcov shape is now (batch, 5,5)
  
  # Difference between prediction and true state vectors
  y_diff = y_pred - y_true

  # n.b. use "batch_dot" and not "dot"!
  y_dot = K.batch_dot(invcov, y_diff)           # y_dot shape is (batch,5,1)
  y_dot = K.reshape(y_dot, (batch_size, 1, 5))  # y_dot shape is now (batch,1,5)
  y_loss = K.batch_dot(y_dot, y_diff)           # y_loss shape is (batch,1,1)
  y_loss = K.reshape(y_loss, (batch_size,))     # y_loss shape is now (batch)
  return y_loss

#--------------------------------------------
# Test loss function
# x_test = x_train[2][0]
# y_test = model.predict([x_train[0][0:1],x_train[1][0:1],x_train[2][0:1]])
# y_test = np.squeeze(y_test)
# inconv_test = x_train[1][0]

# loss = K.eval(customLoss(K.variable([x_test,x_test,x_test]), K.variable([y_test,y_test,y_test]), K.variable([inconv_test,inconv_test,inconv_test])))
# print('loss shape: '    + str(loss.shape)    )
# print(loss)

# %% [markdown]
# ### Metric

# %%
def customMetric(y_true, y_pred, cov, id=0):
  batch_size = tf.shape(y_pred)[0]

  y_pred = K.reshape(y_pred, (batch_size, 5,1)) # y_pred  shape is now (batch, 5,1)
  y_true = K.reshape(y_true, (batch_size, 5,1)) # y_state shape is now (batch, 5,1)
  cov = K.reshape(cov, (batch_size, 5,5)) # cov  shape is now (batch, 5,5)
  # cov = tf.transpose(cov, perm=[0,2,1])     # cov shape is now (batch, 5,5)
  y_diff = y_pred[:,id] - y_true[:,id]
  # y_diff = K.reshape(y_diff, (batch_size,1))
  cov = K.reshape(cov[:,id,id], (batch_size,1))
  # print("diff:\n",y_diff)
  print("cov:\n",cov)
  # return (y_diff*y_diff)/(cov[:,id,id])
  return tf.math.square(y_diff)/(cov)

# ccov = x_train[2][0:6]
# ccov = np.reshape(ccov, (6,5,5))

# print(ccov)

# metric = K.eval(customMetric(y_train[0:6],y_train[1:7],x_train[2][0:6],0))
# print("metric: \n",metric)

# %%
def customMetric(y_true, y_pred, cov, id=0):
  batch_size = tf.shape(y_pred)[0]

  y_pred = K.reshape(y_pred, (batch_size, 1)) # y_pred  shape is now (batch, 5,1)
  y_true = K.reshape(y_true, (batch_size, 1)) # y_state shape is now (batch, 5,1)
  cov = K.reshape(cov, (batch_size, 5,5)) # cov  shape is now (batch, 5,5)
  # cov = tf.transpose(cov, perm=[0,2,1])     # cov shape is now (batch, 5,5)
  print("pred:\n",y_pred)
  y_diff = y_pred - y_true
  # y_diff = K.reshape(y_diff, (batch_size,1))
  cov = K.reshape(cov[:,id,id], (batch_size,1))
  # print("diff:\n",y_diff)
  print("cov:\n",cov)
  print("diff:\n",y_diff)
  # return (y_diff*y_diff)/(cov[:,id,id])
  return tf.math.square(y_diff)/(cov)

# ccov = x_train[2][0:6]
# ccov = np.reshape(ccov, (6,5,5))

# print(ccov)

# metric = K.eval(customMetric(np.expand_dims(y_train[0:6,0],1),np.expand_dims(y_train[1:7,0],1),x_train[2][0:6],3))
# print("metric: \n",metric)

# %% [markdown]
# ## Create Model

# %%
# --==Not in use?==--
# lr_schedule = keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=1e-3,
#     decay_steps=10000,
#     decay_rate=0.8)
from keras.layers import Dense

# nInput = 10
# nInput = 18
nInput = 11

# --==Set seed to get identical results==-- begin
# from tensorflow.random import set_seed
# np.random.seed(1)
# set_seed(2)
# --==Set seed to get identical results==-- end

#--==Set Weights==--
# loss_weights = [1/(sd**2)]
# loss_weights = np.array(loss_weights)/sum(loss_weights)
# model.compile(optimizer=optimizer, loss="mse", loss_weights=loss_weights, metrics=["mae"])

inputs = keras.Input((None,nInput))
# input_true = keras.Input((5,))
input_true = keras.Input((1,))
input_incov = keras.Input((25,))
input_cov_f = keras.Input((25,))
all_inputs = [inputs, input_incov, input_cov_f, input_true]
# all_inputs = [inputs, input_incov, input_true]

# --==Choose model==--
# x = model(inputs)
# x = model_timeless(inputs)
# x = RNNTime(inputs)
x = RNNTimeless(inputs)
# x = RNNTimeStateful(inputs)

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.001)

# outs = {
#     "q_pt":Dense(1, name="q_pt")(x),
#     "phi":Dense(1, name="phi")(x),
#     "tanl":Dense(1, name="tanl")(x),
#     "D":Dense(1, name="D")(x),
#     "z":Dense(1, name="z")(x)
# }

# y_dict = {
#     "q_pt":y_train[:,0],
#     "phi":y_train[:,1],
#     "tanl":y_train[:,2],
#     "D":y_train[:,3],
#     "z":y_train[:,4]
# }

# model = keras.Model(inputs=all_inputs, outputs=outs, name="RNNModel")

model = keras.Model(inputs=all_inputs, outputs=x, name="RNNModel")

# model.add_metric(customMetric(input_true, x, input_cov_f, 0),name="q_pt")
# model.add_metric(customMetric(input_true, x, input_cov_f, 1),name="phi")
# model.add_metric(customMetric(input_true, x, input_cov_f, 2),name="tanl")
# model.add_metric(customMetric(input_true, x, input_cov_f, 3),name="D")
# model.add_metric(customMetric(input_true, x, input_cov_f, 4),name="z")

# model.add_loss(customLoss(input_true, x, input_incov))
# model.compile(loss=None, optimizer=optimizer, metrics=["mae"])

# model.compile(loss="mse", optimizer=optimizer, metrics=["mae"])


model.add_metric(customMetric(input_true, x, input_cov_f, glob_index),name="customMetric")
# try as loss

model.compile(loss="mse", optimizer=optimizer, metrics=["mae"])
# model.compile(loss="", optimizer=optimizer, metrics=["mae"])


model.summary()
# Out:
# pred:
#  Tensor("Reshape:0", shape=(None, 1), dtype=float32)
# cov:
#  Tensor("Reshape_3:0", shape=(None, 1), dtype=float32)
# diff:
#  Tensor("Sub:0", shape=(None, 1), dtype=float32)
# Model: "RNNModel"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 11)]   0
# __________________________________________________________________________________________________
# input_lstm1 (LSTM)              (None, None, 1024)   4243456     input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, 1024)   0           input_lstm1[0][0]
# __________________________________________________________________________________________________
# lstm2 (LSTM)                    (None, None, 512)    3147776     dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, 512)    0           lstm2[0][0]
# __________________________________________________________________________________________________
# lstm3 (LSTM)                    (None, 256)          787456      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           lstm3[0][0]
# __________________________________________________________________________________________________
# Dense1 (Dense)                  (None, 256)          65792       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 256)          0           Dense1[0][0]
# __________________________________________________________________________________________________
# Dense2 (Dense)                  (None, 128)          32896       dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128)          0           Dense2[0][0]
# __________________________________________________________________________________________________
# Dense3 (Dense)                  (None, 64)           8256        dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           Dense3[0][0]
# __________________________________________________________________________________________________
# Dense4 (Dense)                  (None, 32)           2080        dropout_5[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 25)]         0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 25)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# output-Dense (Dense)            (None, 1)            33          Dense4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape (TensorFlowOp [(2,)]               0           output-Dense[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [()]                 0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape/shape (Tens [(2,)]               0           tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_1/shape (Te [(2,)]               0           tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_2/shape (Te [(3,)]               0           tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(None, 1)]          0           output-Dense[0][0]
#                                                                  tf_op_layer_Reshape/shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_1 (TensorFl [(None, 1)]          0           input_2[0][0]
#                                                                  tf_op_layer_Reshape_1/shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_2 (TensorFl [(None, 5, 5)]       0           input_4[0][0]
#                                                                  tf_op_layer_Reshape_2/shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(None, 1)]          0           tf_op_layer_Reshape[0][0]
#                                                                  tf_op_layer_Reshape_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [(None,)]            0           tf_op_layer_Reshape_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_3/shape (Te [(2,)]               0           tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square (TensorFlowO [(None, 1)]          0           tf_op_layer_Sub[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_3 (TensorFl [(None, 1)]          0           tf_op_layer_strided_slice_1[0][0]
#                                                                  tf_op_layer_Reshape_3/shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv (TensorFlow [(None, 1)]          0           tf_op_layer_Square[0][0]
#                                                                  tf_op_layer_Reshape_3[0][0]
# __________________________________________________________________________________________________
# add_metric (AddMetric)          (None, 1)            0           tf_op_layer_RealDiv[0][0]
# ==================================================================================================
# Total params: 8,287,745
# Trainable params: 8,287,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Custom Train

# %%
def concat_hist(H1,H2):
  H = {}
  for i in H1.keys():
    H[i] = list(np.append(np.array(H1[i]),np.array(H2[i])))
  return H
H = None

# %% [markdown]
# ## Use Multi GPU, stragety

# %%
from keras.layers import Dense
from tensorflow import distribute


strategy = distribute.MirroredStrategy()
with strategy.scope():
#     nInput = 18
    nInput = 11
    inputs = keras.Input((None,nInput))
    input_true = keras.Input((1,))
    input_incov = keras.Input((25,))
    input_cov_f = keras.Input((25,))
    all_inputs = [inputs, input_incov, input_cov_f, input_true]
    x = RNNTimeless(inputs)
    optimizer = keras.optimizers.Adam(learning_rate=0.001)
    model = keras.Model(inputs=all_inputs, outputs=x, name="RNNModel")
    model.add_metric(customMetric(input_true, x, input_cov_f, glob_index),name="customMetric")
    model.compile(loss="mse", optimizer=optimizer, metrics=["mae"])
    model.summary()
#     H_t = []
#     es = keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.01, patience=25, mode='min', verbose=1, restore_best_weights=True)
#     H_t.append(model.fit(x=x_train, y=y_train, batch_size=8192, epochs=100, verbose=1, validation_data=(x_test, y_test), shuffle=True).history)
#     if H == None:
#       H = H_t[-1]
#     else:
#       H = concat_hist(H,H_t[-1])
#     final_loss = round(H["loss"][-1],2)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# pred:
#  Tensor("Reshape_12:0", shape=(None, 1), dtype=float32)
# cov:
#  Tensor("Reshape_15:0", shape=(None, 1), dtype=float32)
# diff:
#  Tensor("Sub_3:0", shape=(None, 1), dtype=float32)
# Model: "RNNModel"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, None, 11)]   0
# __________________________________________________________________________________________________
# input_lstm1 (LSTM)              (None, None, 1024)   4243456     input_13[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, None, 1024)   0           input_lstm1[0][0]
# __________________________________________________________________________________________________
# lstm2 (LSTM)                    (None, None, 512)    3147776     dropout_18[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, None, 512)    0           lstm2[0][0]
# __________________________________________________________________________________________________
# lstm3 (LSTM)                    (None, 256)          787456      dropout_19[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 256)          0           lstm3[0][0]
# __________________________________________________________________________________________________
# Dense1 (Dense)                  (None, 256)          65792       dropout_20[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 256)          0           Dense1[0][0]
# __________________________________________________________________________________________________
# Dense2 (Dense)                  (None, 128)          32896       dropout_21[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 128)          0           Dense2[0][0]
# __________________________________________________________________________________________________
# Dense3 (Dense)                  (None, 64)           8256        dropout_22[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 64)           0           Dense3[0][0]
# __________________________________________________________________________________________________
# Dense4 (Dense)                  (None, 32)           2080        dropout_23[0][0]
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 25)]         0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 25)]         0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# output-Dense (Dense)            (None, 1)            33          Dense4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_3 (TensorFlow [(2,)]               0           output-Dense[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_6 (Te [()]                 0           tf_op_layer_Shape_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_12/shape (T [(2,)]               0           tf_op_layer_strided_slice_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_13/shape (T [(2,)]               0           tf_op_layer_strided_slice_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_14/shape (T [(3,)]               0           tf_op_layer_strided_slice_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_12 (TensorF [(None, 1)]          0           output-Dense[0][0]
#                                                                  tf_op_layer_Reshape_12/shape[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_13 (TensorF [(None, 1)]          0           input_14[0][0]
#                                                                  tf_op_layer_Reshape_13/shape[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_14 (TensorF [(None, 5, 5)]       0           input_16[0][0]
#                                                                  tf_op_layer_Reshape_14/shape[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Sub_3 (TensorFlowOp [(None, 1)]          0           tf_op_layer_Reshape_12[0][0]
#                                                                  tf_op_layer_Reshape_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_7 (Te [(None,)]            0           tf_op_layer_Reshape_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_15/shape (T [(2,)]               0           tf_op_layer_strided_slice_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_3 (TensorFlo [(None, 1)]          0           tf_op_layer_Sub_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_15 (TensorF [(None, 1)]          0           tf_op_layer_strided_slice_7[0][0]
#                                                                  tf_op_layer_Reshape_15/shape[0][0
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_3 (TensorFl [(None, 1)]          0           tf_op_layer_Square_3[0][0]
#                                                                  tf_op_layer_Reshape_15[0][0]
# __________________________________________________________________________________________________
# add_metric_3 (AddMetric)        (None, 1)            0           tf_op_layer_RealDiv_3[0][0]
# ==================================================================================================
# Total params: 8,287,745
# Trainable params: 8,287,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
with strategy.scope():
    optimizer = keras.optimizers.Adam(learning_rate=0.0001)
    model = keras.Model(inputs=all_inputs, outputs=x, name="RNNModel")
    model.add_metric(customMetric(input_true, x, input_cov_f, glob_index),name="customMetric")
    model.compile(loss="mse", optimizer=optimizer, metrics=["mae"])
    model.summary()

# %%
H_t = []

# Using custom loss and gen
es = keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.01, patience=25, mode='min', verbose=1, restore_best_weights=True)
# H = model.fit(x=x_train, y=y_train, batch_size=64, epochs=300, validation_data=(x_test, y_test), verbose=1, callbacks=[es])
# H = model.fit(x=x_train, y=y_train, batch_size=64, epochs=300, shuffle=True, verbose=1, callbacks=[es])
# H = model.fit(x=x_train, y=y_train[:,2], batch_size=256, epochs=300, verbose=1, shuffle=True, callbacks=[es])
# H_t.append(model.fit(x=x_train, y=y_train[:,2], batch_size=256, epochs=300, verbose=1, shuffle=True, callbacks=[es]).history)
# H_t.append(model.fit(x=x_train, y=y_train[:,index], batch_size=256, epochs=300, verbose=1, shuffle=True, callbacks=[es]).history)
H_t.append(model.fit(x=x_train, y=y_train, batch_size=8192, epochs=100, verbose=1, validation_data=(x_test, y_test), shuffle=True).history)
# H_t.append(model.fit(x=x_train, y=y_train, batch_size=16000, epochs=25, verbose=1, validation_data=(x_test, y_test), shuffle=True).history)
# model.fit(x=[x_train[0],x_train[1],x_train[2],np.expand_dims(x_train[3][:,index],-1)], y=y_train[:,index], batch_size=256, epochs=300, verbose=1, shuffle=True)
if H == None:
  H = H_t[-1]
else:
  H = concat_hist(H,H_t[-1])
final_loss = round(H["loss"][-1],2)
# H = model.fit(x=x_train, y=y_train, batch_size=64, epochs=100, validation_data=test_gen, validation_steps=50, validation_batch_size=32, verbose=1)

# Example how it kind of looks like
# H = model.fit(x=[x_train, invCov, y_train], y=y_train, batch_size=64, epochs=100, verbose=1)

# Overfit
# es = keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.001, patience=100, mode='min', verbose=1, restore_best_weights=True)
# H = model.fit(x=x_train, y=y_train, batch_size=1, epochs=100, verbose=1, callbacks=[es])
# H = model.fit(x=x_train, y=y_train, batch_size=1, epochs=100, verbose=1, validation_data=(x_test,y_test), callbacks=[es])
# Out:
# Epoch 1/100
# INFO:tensorflow:batch_all_reduce: 19 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 19 all-reduces with algorithm = nccl, num_packs = 1
# 24/24 [==============================] - 25s 1s/step - loss: 148.1822 - mae: 9.0508 - customMetric: 49409.2539 - val_loss: 120.4750 - val_mae: 8.4262 - val_customMetric: 120420.3516
# Epoch 2/100
# 24/24 [==============================] - 22s 909ms/step - loss: 120.6041 - mae: 8.2131 - customMetric: 52051.6016 - val_loss: 119.9141 - val_mae: 8.1274 - val_customMetric: 101574.5078
# Epoch 3/100
# 24/24 [==============================] - 22s 911ms/step - loss: 120.4096 - mae: 8.1972 - customMetric: 50574.4883 - val_loss: 119.7927 - val_mae: 8.2643 - val_customMetric: 110892.7266
# Epoch 4/100
# 24/24 [==============================] - 22s 909ms/step - loss: 120.2079 - mae: 8.1972 - customMetric: 50837.1250 - val_loss: 119.7485 - val_mae: 8.2326 - val_customMetric: 108866.0703
# Epoch 5/100
# 24/24 [==============================] - 22s 909ms/step - loss: 120.1994 - mae: 8.1952 - customMetric: 51240.1641 - val_loss: 119.8868 - val_mae: 8.3018 - val_customMetric: 113204.8438
# Epoch 6/100
# 24/24 [==============================] - 22s 910ms/step - loss: 120.0740 - mae: 8.1998 - customMetric: 52101.9141 - val_loss: 119.7549 - val_mae: 8.2413 - val_customMetric: 109420.0781
# Epoch 7/100
# 24/24 [==============================] - 22s 916ms/step - loss: 119.9904 - mae: 8.1916 - customMetric: 50054.7773 - val_loss: 119.7366 - val_mae: 8.2127 - val_customMetric: 107546.6641
# Epoch 8/100
# 24/24 [==============================] - 22s 906ms/step - loss: 119.9290 - mae: 8.1910 - customMetric: 50256.8438 - val_loss: 119.8884 - val_mae: 8.1319 - val_customMetric: 101892.5234
# Epoch 9/100
# 24/24 [==============================] - 22s 914ms/step - loss: 119.9339 - mae: 8.1951 - customMetric: 51133.9531 - val_loss: 119.7700 - val_mae: 8.1717 - val_customMetric: 104744.3828
# Epoch 10/100
# 24/24 [==============================] - 22s 913ms/step - loss: 119.8681 - mae: 8.1883 - customMetric: 51497.9805 - val_loss: 119.8082 - val_mae: 8.1537 - val_customMetric: 103459.3828
# Epoch 11/100
# 24/24 [==============================] - 22s 920ms/step - loss: 119.8615 - mae: 8.1719 - customMetric: 51920.7070 - val_loss: 119.9488 - val_mae: 8.3229 - val_customMetric: 114429.6250
# Epoch 12/100
# 24/24 [==============================] - 22s 909ms/step - loss: 119.7852 - mae: 8.1815 - customMetric: 51135.9609 - val_loss: 119.7856 - val_mae: 8.1579 - val_customMetric: 103732.2188
# Epoch 13/100
# 24/24 [==============================] - 22s 912ms/step - loss: 119.7865 - mae: 8.1884 - customMetric: 51756.7305 - val_loss: 119.7378 - val_mae: 8.1742 - val_customMetric: 104811.3672
# Epoch 14/100
# 24/24 [==============================] - 22s 918ms/step - loss: 119.6507 - mae: 8.1776 - customMetric: 50778.4609 - val_loss: 119.6711 - val_mae: 8.2452 - val_customMetric: 109400.2656
# Epoch 15/100
# 24/24 [==============================] - 22s 911ms/step - loss: 119.5572 - mae: 8.1734 - customMetric: 50114.5312 - val_loss: 119.6094 - val_mae: 8.2672 - val_customMetric: 110946.9219
# Epoch 16/100
# 24/24 [==============================] - 22s 907ms/step - loss: 119.4946 - mae: 8.1734 - customMetric: 48998.1992 - val_loss: 120.1512 - val_mae: 8.3876 - val_customMetric: 118463.7266
# Epoch 17/100
# 24/24 [==============================] - 22s 900ms/step - loss: 119.6580 - mae: 8.1735 - customMetric: 49794.9766 - val_loss: 119.8079 - val_mae: 8.2751 - val_customMetric: 111572.2891
# Epoch 18/100
# 24/24 [==============================] - 22s 917ms/step - loss: 119.5378 - mae: 8.1849 - customMetric: 50689.5078 - val_loss: 119.8273 - val_mae: 8.1195 - val_customMetric: 100796.1328
# Epoch 19/100
# 24/24 [==============================] - 22s 914ms/step - loss: 119.2606 - mae: 8.1453 - customMetric: 48627.6602 - val_loss: 119.8096 - val_mae: 8.4402 - val_customMetric: 118417.2734
# Epoch 20/100
# 24/24 [==============================] - 22s 918ms/step - loss: 118.6895 - mae: 8.1373 - customMetric: 47304.8867 - val_loss: 118.3112 - val_mae: 8.1443 - val_customMetric: 85068.6172
# Epoch 21/100
# 24/24 [==============================] - 22s 910ms/step - loss: 118.1868 - mae: 8.1038 - customMetric: 45254.4414 - val_loss: 119.1348 - val_mae: 8.2945 - val_customMetric: 114330.5938
# Epoch 22/100
# 24/24 [==============================] - 22s 917ms/step - loss: 118.4304 - mae: 8.1122 - customMetric: 46237.8047 - val_loss: 117.9507 - val_mae: 8.1067 - val_customMetric: 100377.5156
# Epoch 23/100
# 24/24 [==============================] - 22s 911ms/step - loss: 118.1058 - mae: 8.1008 - customMetric: 44621.0039 - val_loss: 117.6096 - val_mae: 8.0896 - val_customMetric: 96718.6484
# Epoch 24/100
# 24/24 [==============================] - 22s 917ms/step - loss: 117.4224 - mae: 8.0363 - customMetric: 42922.2344 - val_loss: 117.3258 - val_mae: 8.0825 - val_customMetric: 84854.0703
# Epoch 25/100
# 24/24 [==============================] - 22s 914ms/step - loss: 117.1286 - mae: 8.0339 - customMetric: 41764.4531 - val_loss: 117.2162 - val_mae: 8.0869 - val_customMetric: 87018.9766
# Epoch 26/100
# 24/24 [==============================] - 22s 916ms/step - loss: 117.0364 - mae: 8.0191 - customMetric: 41301.7266 - val_loss: 116.9272 - val_mae: 8.1525 - val_customMetric: 84893.9766
# Epoch 27/100
# 24/24 [==============================] - 22s 904ms/step - loss: 119.4983 - mae: 8.1601 - customMetric: 50150.6250 - val_loss: 119.9967 - val_mae: 8.3325 - val_customMetric: 115050.7422
# Epoch 28/100
# 24/24 [==============================] - 22s 907ms/step - loss: 119.6727 - mae: 8.1749 - customMetric: 50803.7695 - val_loss: 119.7404 - val_mae: 8.2118 - val_customMetric: 107506.9609
# Epoch 29/100
# 24/24 [==============================] - 22s 905ms/step - loss: 119.5398 - mae: 8.1772 - customMetric: 51650.0898 - val_loss: 119.7490 - val_mae: 8.1920 - val_customMetric: 106169.9609
# Epoch 30/100
# 24/24 [==============================] - 22s 917ms/step - loss: 119.5376 - mae: 8.1736 - customMetric: 51352.5078 - val_loss: 119.8172 - val_mae: 8.1542 - val_customMetric: 103527.1406
# Epoch 31/100
# 24/24 [==============================] - 22s 916ms/step - loss: 119.5401 - mae: 8.1767 - customMetric: 50780.7539 - val_loss: 119.7454 - val_mae: 8.2297 - val_customMetric: 108676.6562
# Epoch 32/100
# 24/24 [==============================] - 22s 913ms/step - loss: 119.6753 - mae: 8.1795 - customMetric: 50860.7227 - val_loss: 119.8827 - val_mae: 8.1344 - val_customMetric: 102087.7969
# Epoch 33/100
# 24/24 [==============================] - 22s 910ms/step - loss: 119.5435 - mae: 8.1793 - customMetric: 50986.4453 - val_loss: 119.8236 - val_mae: 8.1513 - val_customMetric: 103318.9062
# Epoch 34/100
# 24/24 [==============================] - 22s 923ms/step - loss: 119.5675 - mae: 8.1747 - customMetric: 49735.8008 - val_loss: 119.8191 - val_mae: 8.2779 - val_customMetric: 111729.3516
# Epoch 35/100
# 24/24 [==============================] - 22s 915ms/step - loss: 119.6030 - mae: 8.1779 - customMetric: 50404.7383 - val_loss: 119.7688 - val_mae: 8.1725 - val_customMetric: 104807.2656
# Epoch 36/100
# 24/24 [==============================] - 22s 906ms/step - loss: 119.5230 - mae: 8.1762 - customMetric: 50465.3828 - val_loss: 119.7368 - val_mae: 8.1895 - val_customMetric: 105948.9688
# Epoch 37/100
# 24/24 [==============================] - 22s 907ms/step - loss: 119.5375 - mae: 8.1747 - customMetric: 51356.1328 - val_loss: 119.7155 - val_mae: 8.1822 - val_customMetric: 105393.5859
# Epoch 38/100
# 24/24 [==============================] - 22s 905ms/step - loss: 119.5108 - mae: 8.1793 - customMetric: 51674.4258 - val_loss: 119.5643 - val_mae: 8.1596 - val_customMetric: 103159.4062
# Epoch 39/100
# 24/24 [==============================] - 22s 916ms/step - loss: 119.2812 - mae: 8.1643 - customMetric: 48888.3672 - val_loss: 118.8247 - val_mae: 8.1058 - val_customMetric: 96047.1641
# Epoch 40/100
# 24/24 [==============================] - 22s 922ms/step - loss: 118.8162 - mae: 8.1337 - customMetric: 47993.6094 - val_loss: 117.8292 - val_mae: 8.1286 - val_customMetric: 94195.2344
# Epoch 41/100
# 24/24 [==============================] - 22s 908ms/step - loss: 118.2611 - mae: 8.0926 - customMetric: 46837.3281 - val_loss: 118.2191 - val_mae: 8.2971 - val_customMetric: 103230.5859
# Epoch 42/100
# 24/24 [==============================] - 22s 906ms/step - loss: 117.5790 - mae: 8.0612 - customMetric: 44621.6484 - val_loss: 117.7493 - val_mae: 7.9373 - val_customMetric: 70620.0859
# Epoch 43/100
# 24/24 [==============================] - 22s 910ms/step - loss: 117.2018 - mae: 8.0313 - customMetric: 42880.7148 - val_loss: 117.3316 - val_mae: 8.1395 - val_customMetric: 95269.9844
# Epoch 44/100
# 24/24 [==============================] - 22s 921ms/step - loss: 117.0745 - mae: 8.0312 - customMetric: 43194.5430 - val_loss: 117.1166 - val_mae: 8.0590 - val_customMetric: 75663.6484
# Epoch 45/100
# 24/24 [==============================] - 22s 909ms/step - loss: 117.0072 - mae: 8.0314 - customMetric: 42898.3203 - val_loss: 116.9993 - val_mae: 8.0413 - val_customMetric: 77426.4531
# Epoch 46/100
# 24/24 [==============================] - 22s 918ms/step - loss: 117.0466 - mae: 8.0275 - customMetric: 41422.9492 - val_loss: 116.8919 - val_mae: 8.0084 - val_customMetric: 74192.4531
# Epoch 47/100
# 24/24 [==============================] - 22s 910ms/step - loss: 116.4209 - mae: 7.9900 - customMetric: 39474.5000 - val_loss: 116.9374 - val_mae: 8.2614 - val_customMetric: 112798.5469
# Epoch 48/100
# 24/24 [==============================] - 22s 912ms/step - loss: 117.8778 - mae: 8.0782 - customMetric: 45597.4492 - val_loss: 119.7413 - val_mae: 8.2171 - val_customMetric: 107854.2734
# Epoch 49/100
# 24/24 [==============================] - 22s 903ms/step - loss: 119.9227 - mae: 8.1700 - customMetric: 50028.2148 - val_loss: 119.7508 - val_mae: 8.2347 - val_customMetric: 109006.4297
# Epoch 50/100
# 24/24 [==============================] - 22s 910ms/step - loss: 119.5827 - mae: 8.1804 - customMetric: 50662.6250 - val_loss: 119.7690 - val_mae: 8.1765 - val_customMetric: 105106.8984
# Epoch 51/100
# 24/24 [==============================] - 22s 909ms/step - loss: 119.5648 - mae: 8.1726 - customMetric: 50030.6445 - val_loss: 119.7610 - val_mae: 8.1819 - val_customMetric: 105477.3828
# Epoch 52/100
# 24/24 [==============================] - 22s 916ms/step - loss: 119.5387 - mae: 8.1789 - customMetric: 50769.3711 - val_loss: 119.7676 - val_mae: 8.1773 - val_customMetric: 105162.8828
# Epoch 53/100
# 24/24 [==============================] - 22s 907ms/step - loss: 119.6496 - mae: 8.1811 - customMetric: 50776.5195 - val_loss: 119.7547 - val_mae: 8.1868 - val_customMetric: 105817.6172
# Epoch 54/100
# 24/24 [==============================] - 22s 910ms/step - loss: 119.6354 - mae: 8.1772 - customMetric: 50152.0664 - val_loss: 119.8129 - val_mae: 8.1560 - val_customMetric: 103660.2812
# Epoch 55/100
# 24/24 [==============================] - 22s 913ms/step - loss: 119.5128 - mae: 8.1725 - customMetric: 50804.6406 - val_loss: 119.7367 - val_mae: 8.2101 - val_customMetric: 107403.7031
# Epoch 56/100
# 24/24 [==============================] - 22s 923ms/step - loss: 119.5912 - mae: 8.1818 - customMetric: 52060.6484 - val_loss: 119.7766 - val_mae: 8.2552 - val_customMetric: 110320.6875
# Epoch 57/100
# 24/24 [==============================] - 22s 903ms/step - loss: 119.6402 - mae: 8.1743 - customMetric: 50827.3828 - val_loss: 119.7689 - val_mae: 8.1765 - val_customMetric: 105107.7812
# Epoch 58/100
# 24/24 [==============================] - 22s 915ms/step - loss: 119.5076 - mae: 8.1763 - customMetric: 51608.2812 - val_loss: 119.7756 - val_mae: 8.1725 - val_customMetric: 104824.3750
# Epoch 59/100
# 24/24 [==============================] - 22s 912ms/step - loss: 119.5274 - mae: 8.1742 - customMetric: 50990.2266 - val_loss: 119.7922 - val_mae: 8.1641 - val_customMetric: 104237.0391
# Epoch 60/100
# 24/24 [==============================] - 22s 912ms/step - loss: 119.5917 - mae: 8.1819 - customMetric: 51847.2930 - val_loss: 119.7481 - val_mae: 8.1923 - val_customMetric: 106187.0625
# Epoch 61/100
# 24/24 [==============================] - 22s 907ms/step - loss: 119.5310 - mae: 8.1697 - customMetric: 51471.8750 - val_loss: 119.7902 - val_mae: 8.2639 - val_customMetric: 110862.3984
# Epoch 62/100
# 24/24 [==============================] - 22s 915ms/step - loss: 119.6415 - mae: 8.1840 - customMetric: 50105.9844 - val_loss: 119.7525 - val_mae: 8.1860 - val_customMetric: 105751.9922
# Epoch 63/100
# 24/24 [==============================] - 22s 915ms/step - loss: 119.5743 - mae: 8.1768 - customMetric: 50642.4453 - val_loss: 119.8085 - val_mae: 8.1548 - val_customMetric: 103549.9844
# Epoch 64/100
# 24/24 [==============================] - 22s 911ms/step - loss: 119.5193 - mae: 8.1771 - customMetric: 52119.1055 - val_loss: 119.7734 - val_mae: 8.1626 - val_customMetric: 104034.2734
# Epoch 65/100
# 24/24 [==============================] - 22s 910ms/step - loss: 119.4909 - mae: 8.1682 - customMetric: 50863.6367 - val_loss: 119.5346 - val_mae: 8.2406 - val_customMetric: 107857.8281
# Epoch 66/100
# 24/24 [==============================] - 22s 915ms/step - loss: 119.3576 - mae: 8.1645 - customMetric: 49684.8516 - val_loss: 120.2442 - val_mae: 8.3954 - val_customMetric: 118548.0547
# Epoch 67/100
# 24/24 [==============================] - 22s 908ms/step - loss: 119.6875 - mae: 8.1831 - customMetric: 52002.0117 - val_loss: 119.8082 - val_mae: 8.2797 - val_customMetric: 111759.1797
# Epoch 68/100
# 24/24 [==============================] - 22s 913ms/step - loss: 119.4543 - mae: 8.1673 - customMetric: 50347.9062 - val_loss: 119.1050 - val_mae: 8.2395 - val_customMetric: 106896.8750
# Epoch 69/100
# 24/24 [==============================] - 22s 912ms/step - loss: 119.5663 - mae: 8.1721 - customMetric: 49792.4258 - val_loss: 119.9709 - val_mae: 8.3264 - val_customMetric: 114693.3359
# Epoch 70/100
# 24/24 [==============================] - 22s 917ms/step - loss: 119.5511 - mae: 8.1779 - customMetric: 50674.8672 - val_loss: 119.8427 - val_mae: 8.1461 - val_customMetric: 102946.9219
# Epoch 71/100
# 24/24 [==============================] - 22s 906ms/step - loss: 119.5284 - mae: 8.1750 - customMetric: 51095.3086 - val_loss: 119.7711 - val_mae: 8.1752 - val_customMetric: 105013.3359
# Epoch 72/100
# 24/24 [==============================] - 22s 916ms/step - loss: 119.4871 - mae: 8.1773 - customMetric: 51090.6094 - val_loss: 119.7872 - val_mae: 8.1667 - val_customMetric: 104418.6406
# Epoch 73/100
# 24/24 [==============================] - 22s 917ms/step - loss: 119.5727 - mae: 8.1786 - customMetric: 50557.9766 - val_loss: 119.7951 - val_mae: 8.1631 - val_customMetric: 104162.8359
# Epoch 74/100
# 24/24 [==============================] - 22s 916ms/step - loss: 119.5151 - mae: 8.1742 - customMetric: 50348.9570 - val_loss: 119.7686 - val_mae: 8.1764 - val_customMetric: 105099.4062
# Epoch 75/100
# 24/24 [==============================] - 22s 907ms/step - loss: 119.5183 - mae: 8.1762 - customMetric: 50821.3242 - val_loss: 119.7401 - val_mae: 8.2142 - val_customMetric: 107662.4453
# Epoch 76/100
# 24/24 [==============================] - 22s 915ms/step - loss: 119.4995 - mae: 8.1741 - customMetric: 51043.7422 - val_loss: 119.7988 - val_mae: 8.1612 - val_customMetric: 104026.0625
# Epoch 77/100
# 24/24 [==============================] - 22s 909ms/step - loss: 119.6321 - mae: 8.1832 - customMetric: 49977.8281 - val_loss: 119.8809 - val_mae: 8.1349 - val_customMetric: 102126.5781
# Epoch 78/100
# 24/24 [==============================] - 22s 921ms/step - loss: 119.5349 - mae: 8.1755 - customMetric: 50772.6367 - val_loss: 119.7653 - val_mae: 8.1775 - val_customMetric: 105167.0938
# Epoch 79/100
# 24/24 [==============================] - 22s 921ms/step - loss: 119.5127 - mae: 8.1710 - customMetric: 51334.3594 - val_loss: 119.8109 - val_mae: 8.1550 - val_customMetric: 103571.7031
# Epoch 80/100
# 24/24 [==============================] - 22s 925ms/step - loss: 119.5124 - mae: 8.1760 - customMetric: 50471.3086 - val_loss: 119.7789 - val_mae: 8.1671 - val_customMetric: 104419.5859
# Epoch 81/100
# 24/24 [==============================] - 22s 912ms/step - loss: 119.5055 - mae: 8.1682 - customMetric: 49925.5430 - val_loss: 119.7300 - val_mae: 8.2200 - val_customMetric: 107997.3281
# Epoch 82/100
# 24/24 [==============================] - 22s 907ms/step - loss: 119.4866 - mae: 8.1748 - customMetric: 51379.9805 - val_loss: 119.7275 - val_mae: 8.1763 - val_customMetric: 104960.5938
# Epoch 83/100
# 24/24 [==============================] - 22s 904ms/step - loss: 119.3812 - mae: 8.1717 - customMetric: 49164.7461 - val_loss: 119.6599 - val_mae: 8.1807 - val_customMetric: 105070.3438
# Epoch 84/100
# 24/24 [==============================] - 22s 902ms/step - loss: 119.3677 - mae: 8.1728 - customMetric: 50391.1250 - val_loss: 119.3868 - val_mae: 8.1212 - val_customMetric: 98723.4688
# Epoch 85/100
# 24/24 [==============================] - 22s 914ms/step - loss: 119.2767 - mae: 8.1621 - customMetric: 50758.4336 - val_loss: 119.4041 - val_mae: 8.1839 - val_customMetric: 105678.0391
# Epoch 86/100
# 24/24 [==============================] - 22s 910ms/step - loss: 119.2344 - mae: 8.1473 - customMetric: 48260.5742 - val_loss: 118.5574 - val_mae: 8.1240 - val_customMetric: 100946.3438
# Epoch 87/100
# 24/24 [==============================] - 22s 902ms/step - loss: 128.4235 - mae: 8.4529 - customMetric: 50842.7070 - val_loss: 120.5989 - val_mae: 8.0413 - val_customMetric: 94523.9219
# Epoch 88/100
# 24/24 [==============================] - 22s 904ms/step - loss: 120.1434 - mae: 8.1984 - customMetric: 51268.8242 - val_loss: 120.0723 - val_mae: 8.0983 - val_customMetric: 99340.3828
# Epoch 89/100
# 24/24 [==============================] - 21s 895ms/step - loss: 119.9155 - mae: 8.1796 - customMetric: 50142.5273 - val_loss: 119.7413 - val_mae: 8.2175 - val_customMetric: 107882.2109
# Epoch 90/100
# 24/24 [==============================] - 22s 923ms/step - loss: 119.8105 - mae: 8.1798 - customMetric: 50982.3203 - val_loss: 119.8285 - val_mae: 8.1506 - val_customMetric: 103276.4453
# Epoch 91/100
# 24/24 [==============================] - 22s 896ms/step - loss: 119.5871 - mae: 8.1784 - customMetric: 51217.9688 - val_loss: 119.7702 - val_mae: 8.2510 - val_customMetric: 110053.7031
# Epoch 92/100
# 24/24 [==============================] - 22s 897ms/step - loss: 119.6939 - mae: 8.1836 - customMetric: 50554.9688 - val_loss: 119.7514 - val_mae: 8.1901 - val_customMetric: 106043.7656
# Epoch 93/100
# 24/24 [==============================] - 22s 912ms/step - loss: 119.5765 - mae: 8.1767 - customMetric: 50687.4609 - val_loss: 119.7424 - val_mae: 8.2214 - val_customMetric: 108140.8203
# Epoch 94/100
# 24/24 [==============================] - 22s 904ms/step - loss: 119.6268 - mae: 8.1813 - customMetric: 51479.5625 - val_loss: 119.7883 - val_mae: 8.1663 - val_customMetric: 104390.3125
# Epoch 95/100
# 24/24 [==============================] - 22s 906ms/step - loss: 119.6531 - mae: 8.1764 - customMetric: 50508.8633 - val_loss: 119.7652 - val_mae: 8.1790 - val_customMetric: 105279.0547
# Epoch 96/100
# 24/24 [==============================] - 22s 904ms/step - loss: 119.6254 - mae: 8.1776 - customMetric: 50330.1562 - val_loss: 119.7537 - val_mae: 8.1879 - val_customMetric: 105889.2344
# Epoch 97/100
# 24/24 [==============================] - 22s 901ms/step - loss: 119.5040 - mae: 8.1768 - customMetric: 50608.4648 - val_loss: 119.8152 - val_mae: 8.1553 - val_customMetric: 103608.4766
# Epoch 98/100
# 24/24 [==============================] - 22s 900ms/step - loss: 119.5222 - mae: 8.1757 - customMetric: 50494.0977 - val_loss: 119.7881 - val_mae: 8.1664 - val_customMetric: 104397.0781
# Epoch 99/100
# 24/24 [==============================] - 22s 903ms/step - loss: 119.6031 - mae: 8.1758 - customMetric: 49865.2070 - val_loss: 119.7775 - val_mae: 8.2557 - val_customMetric: 110351.0703
# Epoch 100/100
# 24/24 [==============================] - 22s 902ms/step - loss: 119.5606 - mae: 8.1762 - customMetric: 50883.0469 - val_loss: 119.7833 - val_mae: 8.1687 - val_customMetric: 104561.2031

# %% [markdown]
# # Save model

# %%
model_index = 1 # not the right index, dont change this one...
date = "03-25(2)"
def gen_name(m_type):
    global model_index, glob_index, date, final_loss
    variable = ["q_pt","phi","tanl","D","z"][glob_index]
    m_str = "models/" + str(date) + "-2021_" + str(variable) + "-" + str(model_index) + "_loss=" + str(final_loss) + "." + str(m_type)
    model_index+=1 # create a check for if file exists, for now just increment
    return m_str

# %%
# model.save('model.h5', save_format="h5")
# TODO check if file exists, increment counter
# model.save('drive/MyDrive/Models/RealRNN_1-3-2021_141Ep_Onlytanl-2.h5', save_format="h5")
model.save(gen_name("h5"), save_format="h5")

# %% [markdown]
# ## Graph loss and mae

# %%
print(H.keys())
# print("loss: ", H["loss"])
# print("mae: ", H["mae"])
# print("val_loss: ", H.history["val_loss"])
# print("val_mae: ", H.history["val_mae"])

lim = 0

fig, ax = plt.subplots(3,1,figsize=(5,15))
fig.subplots_adjust(hspace=0.35)

ax[0].plot(H["loss"][lim:])
ax[0].plot(H["val_loss"][lim:])
ax[0].set_title("loss vs epoch", fontsize=20)
ax[0].set_xlabel("epoch", fontsize=15)
ax[0].set_ylabel("loss", fontsize=15)
ax[0].legend(["train","val"])
ax[0].grid(True)


ax[1].plot(H["mae"][lim:])
ax[1].plot(H["val_mae"][lim:])
ax[1].set_title("mae vs epoch", fontsize=20)
ax[1].set_xlabel("epoch", fontsize=15)
ax[1].set_ylabel("mae", fontsize=15)
ax[1].legend(["train","val"])
ax[1].grid(True)

ax[2].plot(H["customMetric"][lim:])
ax[2].plot(H["val_customMetric"][lim:])
ax[2].set_title("metric vs epoch", fontsize=20)
ax[2].set_xlabel("epoch", fontsize=15)
ax[2].set_ylabel("metric", fontsize=15)
ax[2].legend(["train","val"])
ax[2].grid(True)

model_index -= 1
plt.savefig(gen_name("png"))
# Out:
# dict_keys(['loss', 'mae', 'customMetric', 'val_loss', 'val_mae', 'val_customMetric'])

# %%
pred = model.predict(x_test)

diff = pred - y_test
plt.scatter(y_test,pred,)
plt.xlabel("true")
plt.ylabel("pred")
plt.plot([0,3000],[0,3000])
plt.grid(True)
# plt.xlim(-10, 1000)
# plt.ylim(-10, 500)
plt.xlim(-5, 100)
plt.ylim(-5, 100)
plt.show()

plt.scatter(y_test,diff)
plt.xlabel("true")
plt.ylabel("diff")
plt.grid(True)
plt.plot([0,3000],[0,0])
plt.xlim(0, 100)
plt.ylim(-200, 200)
plt.show()

# %%
pred = model.predict(x_train)
print(pred.shape)
print(y_train.shape)

diff = pred - y_train
plt.hist2d(y_train[:,0],pred[:,0],bins=[50,50],range=[[-2,25],[-2,25]])
plt.xlabel("true")
plt.ylabel("pred")
plt.plot([0,3000],[0,3000])
plt.grid(True)
# plt.xlim(-10, 1000)
# plt.ylim(-10, 500)
# plt.xlim(-10, 200)
# plt.ylim(-10, 100)
plt.show()


plt.scatter(y_train,pred,s=1)
plt.xlabel("true")
plt.ylabel("pred")
plt.plot([0,3000],[0,3000])
plt.grid(True)
# plt.xlim(-10, 1000)
# plt.ylim(-10, 500)
plt.xlim(-5, 100)
plt.ylim(-5, 100)
plt.show()

plt.scatter(y_train,diff)
plt.xlabel("true")
plt.ylabel("diff")
plt.grid(True)
plt.plot([0,3000],[0,0])
plt.xlim(0, 100)
plt.ylim(-200, 200)
plt.show()



cov = x_train[2][:,12]
print(cov.shape);
print(y_train.shape)

plt.scatter(y_train[:,0],cov,s=1)
plt.xlabel("true")
plt.ylabel("cov")
plt.grid(True)
# plt.xlim(-10, 1000)
# plt.ylim(-10, 500)
plt.xlim(0, 10)
plt.ylim(0, 1000)
plt.show()


# plt.hist2d(y_train[:,0],diff[:,0],bins=[100,100],range=[[0,200],[-20,20]])
plt.hist(y_train[:,0],bins=100,range=[100,200])
plt.xlabel("true")
plt.ylabel("diff")
# plt.grid(True)
# plt.plot([0,3000],[0,0])
# plt.xlim(0, 00)
# plt.ylim(-1000, 200)
plt.show()
# Out:
# (322046, 1)
# (322046, 1)
# (322046,)
# (322046, 1)

# %%
an_array = np.array(list(H.items()))
save_array = np.array([an_array[0][1],an_array[1][1]])
model_index -= 1
np.save(gen_name("npy"),save_array,allow_pickle=True)

# %% [markdown]
# # Test Model

# %%
np.set_printoptions(suppress=True, precision=3)
from time import sleep

for i in range(10):
  aax = x_train[0][i:i+1]
  oax = x_train[1][i:i+1]
  cax = x_train[2][i:i+1]
  yax = x_train[3][i:i+1]
  aay = y_train[i][index]
  pred = model.predict([aax, oax, cax, yax])[0][0]
  diff = pred - aay
  # print("i: ",i)
  # print("aax:  ",aax[0,0])
  print("aay:  ",aay)
  print("pred: ",pred)
  # print("diff: ",diff)
  print("")

  # plt.plot(aay[0])
  # plt.plot(pred[0])
  # plt.show()
# [Q/PT, phi, tanl, D, z]

# %% [markdown]
# # Load Model

# %%
# model.save('drive/MyDrive/RealRNN_1-2-2021_2.h5', save_format="h5")
# model = keras.models.load_model('drive/MyDrive/Models/RealRNN_1-3-2021_300Ep_Onlyphi.h5')
model = keras.models.load_model('models/03-25-2021_tanl-1_loss=22.48.h5')

# %% [markdown]
# # Graphs

# %%
print(H.keys())
# print("loss: ", H["loss"])
# print("mae: ", H["mae"])
# print("val_loss: ", H.history["val_loss"])
# print("val_mae: ", H.history["val_mae"])

lim = 0

if len(H.keys()) > 4:
  # fig, ax = plt.subplots(4,1,figsize=(5,20))
  fig, ax = plt.subplots(3,1,figsize=(5,15))
  fig.subplots_adjust(hspace=0.35)

  ax[0].plot(H["loss"][lim:])
  # ax[0].plot(H.history["val_loss"][lim:])
  ax[0].set_title("loss vs epoch", fontsize=20)
  ax[0].set_xlabel("epoch", fontsize=15)
  ax[0].set_ylabel("loss", fontsize=15)
  # ax[0].set_yscale("log")
  ax[0].legend(["train","val"])
  ax[0].grid(True)


  ax[1].plot(H["mae"][lim:])
  # ax[1].plot(H.history["val_mae"][lim:])
  ax[1].set_title("mae vs epoch", fontsize=20)
  ax[1].set_xlabel("epoch", fontsize=15)
  ax[1].set_ylabel("mae", fontsize=15)
  ax[1].legend(["train","val"])
  ax[1].grid(True)

  ax[2].plot(H["q_pt"][lim:])
  ax[2].plot(H["phi"][lim:])
  ax[2].plot(H["tanl"][lim:])
  ax[2].plot(H["D"][lim:])
  ax[2].plot(H["z"][lim:])
  ax[2].set_title("data vs epoch", fontsize=20)
  ax[2].set_xlabel("epoch", fontsize=15)
  ax[2].set_ylabel("data", fontsize=15)
  ax[2].legend(["q_pt","phi","tanl","D","z"])
  # ax[2].legend(["phi","tanl","D","z"])
  # ax[2].legend(["phi","D","z"])
  ax[2].grid(True)

  # ax[3].plot(H.history["val_q_pt"][lim:])
  # ax[3].plot(H.history["val_phi"][lim:])
  # ax[3].plot(H.history["val_tanl"][lim:])
  # ax[3].plot(H.history["val_D"][lim:])
  # ax[3].plot(H.history["val_z"][lim:])
  # ax[3].set_title("data vs epoch", fontsize=20)
  # ax[3].set_xlabel("epoch", fontsize=15)
  # ax[3].set_ylabel("data", fontsize=15)
  # ax[3].legend(["val_q_pt","val_phi","val_tanl","val_D","val_z"])
  # # ax[3].legend(["val_phi","val_tanl","val_D","val_z"])
  # # ax[3].legend(["val_phi","val_D","val_z"])
  # ax[3].grid(True)

else:
  fig, ax = plt.subplots(2,1,figsize=(5,10))
  fig.subplots_adjust(hspace=0.35)

  ax[0].plot(H["loss"][lim:])
  # ax[0].plot(H.history["val_loss"][lim:])
  ax[0].set_title("loss vs epoch", fontsize=20)
  ax[0].set_xlabel("epoch", fontsize=15)
  ax[0].set_ylabel("loss", fontsize=15)
  # ax[0].set_yscale("log")
  ax[0].legend(["train","val"])
  ax[0].grid(True)


  ax[1].plot(H["mae"][lim:])
  # ax[1].plot(H.history["val_mae"][lim:])
  ax[1].set_title("mae vs epoch", fontsize=20)
  ax[1].set_xlabel("epoch", fontsize=15)
  ax[1].set_ylabel("mae", fontsize=15)
  ax[1].legend(["train","val"])
  ax[1].grid(True)

# %%
print(H.history.keys())
print("loss: ", H.history["loss"])
print("mae: ", H.history["mae"])
# print("val_loss: ", H.history["val_loss"])
# print("val_mae: ", H.history["val_mae"])

lim = 2

fig, ax = plt.subplots(2,1,figsize=(5,10))
fig.subplots_adjust(hspace=0.35)

ax[0].plot(H.history["loss"][lim:])
# ax[0].plot(H.history["val_loss"][lim:])
ax[0].set_title("loss vs epoch", fontsize=20)
ax[0].set_xlabel("epoch", fontsize=15)
ax[0].set_ylabel("loss", fontsize=15)
ax[0].set_yscale("log")
ax[0].legend(["train","val"])
ax[0].grid(True)


ax[1].plot(H.history["mae"][lim:])
# ax[1].plot(H.history["val_mae"][lim:])
ax[1].set_title("mae vs epoch", fontsize=20)
ax[1].set_xlabel("epoch", fontsize=15)
ax[1].set_ylabel("mae", fontsize=15)
ax[1].legend(["train","val"])
ax[1].grid(True)

# %% [markdown]
# ## UV GRAPHS

# %%
x_train[0][0].shape[0] # (event,hits,18)

# %%
from time import sleep
for z in range(10):
    col = 1
    row = 2
#     fig, ax = plt.subplots(row,col,figsize=(5*col,5*row))
    
    fig = plt.figure()
    gs = fig.add_gridspec(row, col, hspace=0, wspace=0)
    ax = gs.subplots(sharex='col', sharey='row')
    
#     fig.subplots_adjust(hspace=0.5)
    u_hits = []
    v_hits = []
    z_hits = []
    for i in range(x_train[0][z].shape[0]):
        u_hits.append(x_train[0][z][i][0])
        v_hits.append(x_train[0][z][i][1])
        z_hits.append(x_train[0][z][i][6])
    ax[0].plot(z_hits,u_hits,"o")
#     ax[0].x_label("z_hits")
#     ax[0].y_label("u_hits")
    ax[1].plot(z_hits,v_hits,"o")
#     ax[1].x_label("z_hits")
#     ax[1].x_label("v_hits")

# %% [markdown]
# # Graphs

# %%
# Maybe copy over previous function and edit that?
def graph(pred, true, diff):

  values = ["u","v","sin(v)","cos(v)","sin(u)","cos(u)","s","ds","wire","glayer","z","time","dE_amp","q"]
  limits = [["todo"]]

  size = len(values)

  fig, axs = plt.subplots(4,size,figsize=(size*5,20))
  fig.subplots_adjust(wspace=0.3, hspace=0.3)


  for i in range(size):
    (mu, sigma) = norm.fit(diff[:,i])
    print("data" , values[i] ," |: mu: ", mu, "sigma: " , sigma)
    _, bins, _ = axs[0,i].hist(diff[:,i], 20, density=True)
    y = norm.pdf(bins, mu, sigma)
    l = axs[0,i].plot(bins, y, 'r--', linewidth=2)

    axs[0,i].set_title(values[i] + ' diff')
    axs[0,i].set_ylabel('freq')
    axs[0,i].set_xlabel(values[i] + ' diff')

  #--------------------------------------
  # PREDICTED VS TRUE
  #--------------------------------------
    
  for i in range(size):
    axs[1,i].scatter(true[:,i],pred[:,i])
    axs[1,i].grid(True)

    axs[1,i].set_title(values[i] + ' (predicted vs true)')
    axs[1,i].set_ylabel('pred ' + values[i])
    axs[1,i].set_xlabel('true ' + values[i])

    # axs[1,i].set_xlim(limits[i])
    # axs[1,i].set_ylim(limits[i])
    # axs[1,i].plot(limits[i],limits[i], color='b')

  #--------------------------------------
  # DIFFERENCE VS TRUE
  #--------------------------------------

  for i in range(size):
    axs[2,i].scatter(true[:,i],diff[:,i])
    l, r = axs[2,i].get_xlim()
    axs[2,i].hlines(0, l, r)
    axs[2,i].grid(True)

    axs[2,i].set_title(values[i] + ' (difference vs true)')
    axs[2,i].set_ylabel('diff ' + values[i])
    axs[2,i].set_xlabel('true ' + values[i])

  #--------------------------------------
  # DIFFERENCE VS TRUE 2D HIST
  #--------------------------------------

  for i in range(size):
    axs[3,i].hist2d(true[:,i],diff[:,i],bins=20)

    axs[2,i].set_title(values[i] + ' (difference vs true)')
    axs[2,i].set_ylabel('diff ' + values[i])
    axs[2,i].set_xlabel('true ' + values[i])

  fig.show()

# %%
def gen_test_data(x_test, y_test, size=1000):
  pred = model.predict(x_test)
  diff = pred - y_test
  return pred, y_test, diff

# %%
graph(gen_test_data(x_test, y_test));

# %% [markdown]
# # Test model

# %%
# make test function

# %% [markdown]
# # Verification of proper data processing

# %% [markdown]
# ## Using Generator

# %%
aax, aay = next(train_gen)
print(aax.shape)
print(aay.shape)

# %%
print("x",aax[0])
print("y",aay[0])

# %% [markdown]
# ## Non Genenerator

# %%
for i in range(10):
  aax = x_train[i]
  aay = y_train[i]
  # print(aax.shape)
  # print(aay.shape)
  # print("x",aax)
  print("y",aay)

# %% [markdown]
# ## Graphs of Data

# %% [markdown]
# ### filter_ignore
#
# Filters out large and small values and graphs them

# %%
def filter_ignore(var,min=None,max=None,bins=25,ylog=False,xlog=False,cut=True):
  list_ignore = []

  print("--== {} ==--\n".format(var))

  largest = 0
  smallest = 0
  for i in range(len(csv_train[var])):
    if csv_train[var][i] > csv_train[var][largest]:
      largest = i
    if csv_train[var][i] < csv_train[var][smallest]:
      smallest = i
  print("largest value:  ({}, {:.3f})".format(largest,csv_train[var][largest]))
  print("smallest value: ({}, {:.3f})".format(smallest,csv_train[var][smallest]))

  print("")

  if min:
    for i in range(len(csv_train[var])):
      if csv_train[var][i] < min:
        list_ignore.append(i)
    print("min IDs to ignore for '{}':".format(var))
    print(csv_train[var][list_ignore])
    print("")
  if max:
    for i in range(len(csv_train[var])):
      if csv_train[var][i] > max:
        list_ignore.append(i)
    print("max IDs to ignore for '{}':".format(var))
    print(csv_train[var][list_ignore])
    print("")
  if min and max:
    print("total IDs to ignore for '{}':".format(var))
    print(csv_train[var][list_ignore])
    print("")
    plt.hist(csv_train[var],range=[min,max],bins=bins)
  elif min:
    plt.hist(csv_train[var],range=[min,csv_train[var][largest]],bins=bins)
  elif max:
    plt.hist(csv_train[var],range=[csv_train[var][smallest],max],bins=bins)
  else:
    plt.hist(csv_train[var],bins=bins)
  
  plt.title(var)
  if cut:
    plt.xlim(left=min,right=max)
  if ylog:
    plt.yscale("log")
  if xlog:
    plt.xscale("log")
  plt.show()
  return list_ignore

# %%
filter_ignore("q_over_pt",min=-4000,bins=30,ylog=True)

# %%
filter_ignore("tanl",max=1000,bins=25,ylog=True)

# %%
rms_ignore = filter_ignore("rms",max=0.1,bins=25,ylog=True)

# %%
# 'q_over_pt', 'phi', 'tanl', 'D', 'z'
# filter_ignore("D", min=-200, ylog=True,bins=25)
filter_ignore("z",bins=100)

# %%
csv_train.keys()

# %% [markdown]
# ### 1D Hist of all Data

# %%
plt.hist(csv_train["phi"],bins=50) # -3 to 3, even distrib
plt.title("phi")
plt.show()
# ---
plt.hist(csv_train["D"],range=[-3000,80],bins=25) # -3000 to 50, but val in 65
plt.yscale("log")
plt.title("D")
plt.show()
# ---
plt.hist(csv_train["z"],bins=100)
plt.title("z")
plt.show()

# %%
plt.hist(csv_train["cov_44"],range=[0,1000],bins=25)
# plt.yscale("log")
plt.title("cov_44")
plt.show()

# %%
# fig, ax = plt.subplots(2,1,figsize=(5,10))
# fig.subplots_adjust(hspace=0.35)

plt.hist(csv_train["cov_00"],range=[0,1e8],bins=25) # 0 to 1e13
plt.yscale("log")
plt.title("cov_00")
plt.show()
# ---
plt.hist(csv_train["cov_01"],bins=25) # -1e6 to over 1e5
plt.yscale("log")
plt.title("cov_44")
plt.show()
# ---
plt.hist(csv_train["chisq"],bins=25) # 0 to 200
plt.yscale("log")
plt.title("chisq")
plt.show()
# ---
plt.hist(csv_train["Ndof"],range=[0,44],bins=45) # ? this one weird 0 to ~43
plt.yscale("log")
plt.title("Ndof")
plt.show()
# ---
plt.hist(csv_train["rms"],range=[0,0.1],bins=25) # 
# plt.xscale("log")
plt.yscale("log")
plt.title("rms")
plt.show()
# ---
# plt.hist(csv_train["t_start_cntr"],bins=25) # -60 to ~50
plt.hist(csv_train[csv_train["t_start_cntr_valid"] == 1]["t_start_cntr"],bins=25) # -60 to ~50
plt.title("t_start_cntr")
plt.show()

# plt.hist(csv_train["t_tof"],bins=25) # ~-120 to ~175
plt.hist(csv_train[csv_train["t_tof_valid"] == 1]["t_tof"],bins=25) # ~-120 to ~175
plt.title("t_tof")
plt.show()
plt.hist(csv_train["t_bcal"],bins=25) # ~-22 to 20
plt.title("t_bcal")
plt.show()
plt.hist(csv_train["t_fcal"],bins=25) # ~-100 to ~75
plt.yscale("log")
plt.title("t_fcal")
plt.show()
# ---
plt.hist(csv_train["t_start_cntr_valid"],bins=25) # a lot more 0s
plt.title("t_start_cntr_valid")
plt.show()
plt.hist(csv_train["t_tof_valid"],bins=25) # about 5050
plt.title("t_tof_valid")
plt.show()
plt.hist(csv_train["t_bcal_valid"],bins=25) # almost all 0s
plt.title("t_bcal_valid")
plt.show()
plt.hist(csv_train["t_fcal_valid"],bins=25) # almost all 0s
plt.title("t_fcal_valid")
plt.show()
# ---

# %% [markdown]
# ### 1D Hist of Hit1 Data

# %%
plt.hist(csv_train["hit1_u"],bins=25) # -42 to 42
plt.title("hit1_u")
plt.show()
plt.hist(csv_train["hit1_v"],bins=25) # -42 to 42
plt.title("hit1_v")
plt.show()
# plt.hist(csv_train["hit1_sinv"],bins=25) # most are 0.96603 almost all are around that though
# plt.title("hit1_sinv")
# plt.show()
# plt.hist(csv_train["hit1_cosv"],bins=25) # most -0.2585
# plt.title("hit1_cosv")
# plt.show()
# plt.hist(csv_train["hit1_sinu"],bins=25) # most 0.96585
# plt.title("hit1_sinu")
# plt.show()
# plt.hist(csv_train["hit1_cosu"],bins=25) # most 0.2591
# plt.title("hit1_cosu")
# plt.show()
plt.hist(csv_train["hit1_s"],bins=25) # -42 to 42
plt.title("hit1_s")
plt.show()
plt.hist(csv_train["hit1_ds"],bins=25) # 0.01 to 0.04
plt.title("hit1_ds")
plt.show()
plt.hist(csv_train["hit1_wire"],bins=101,range=[0,100]) # 0 to 100
plt.title("hit1_wire")
plt.show()
plt.hist(csv_train["hit1_glayer"],bins=25,range=[0,26]) # 6 to 23
plt.title("hit1_glayer")
plt.show()
plt.hist(csv_train["hit1_z"],bins=25) # spaced out between 180 and 340
plt.title("hit1_z")
plt.show()
plt.hist(csv_train["hit1_time"],bins=25) # -75 to 270
plt.title("hit1_time")
plt.show()
plt.hist(csv_train["hit1_dE_amp"],bins=25) # 0 to 2e-7
plt.title("hit1_dE_amp")
plt.show()
plt.hist(csv_train["hit1_q"],bins=25) # 0 to 85
plt.yscale("log")
plt.title("hit1_q")
plt.show()
# ---

# %% [markdown]
# ### 2D Scatters of various data

# %%
plt.scatter(csv_train["tanl"],abs(csv_train["q_over_pt"]),s=0.01) # a lot more 0s
plt.title("q_over_pt vs tanl")
plt.xlabel("tanl")
plt.ylabel("q_over_pt")
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# %%
# all create a plus sign
plt.scatter(csv_train["t_start_cntr"],csv_train["t_tof"]) # a lot more 0s
plt.title("t_tof vs t_start_cntr")
plt.xlabel("t_start_cntr")
plt.ylabel("t_tof")
plt.show()

# plt.hist(csv_train["t_start_cntr"],bins=25) # -60 to ~50
# plt.hist(csv_train["t_tof"],bins=25) # ~-120 to ~175
# plt.hist(csv_train["t_bcal"],bins=25) # ~-22 to 20
# plt.hist(csv_train["t_fcal"],bins=25) # ~-100 to ~75

# %%
plt.hist(csv_train["hit1_glayer"],bins=24)
plt.hist(csv_train["hit2_glayer"],bins=24)
plt.hist(csv_train["hit3_glayer"],bins=24)
plt.hist(csv_train["hit4_glayer"],bins=24)
plt.hist(csv_train["hit5_glayer"],bins=24)
plt.hist(csv_train["hit6_glayer"],bins=24)
plt.hist(csv_train["hit10_glayer"],bins=24)
plt.show()

# %% [markdown]
# ### 2D Scatters of various hit data

# %%
# Oval
plt.scatter(csv_train["hit1_u"],csv_train["hit1_v"]) # -3 to 3, even distrib
plt.title("v vs u")
plt.xlabel("u")
plt.ylabel("v")
plt.show()

# like a flame
plt.scatter(csv_train["hit1_s"],csv_train["hit1_ds"]) # -3 to 3, even distrib
plt.title("ds vs s")
plt.xlabel("s")
plt.ylabel("ds")
plt.show()

# hit1_wire, with single letters, forms an oval
plt.scatter(csv_train["hit1_wire"],csv_train["hit1_s"]) # -3 to 3, even distrib
plt.title("hit1_s vs hit1_wire")
plt.xlabel("hit1_wire")
plt.ylabel("hit1_s")
plt.show()

# go up in steps
plt.scatter(csv_train["hit1_glayer"],csv_train["hit1_z"]) # -3 to 3, even distrib
plt.title("z vs glayer")
plt.xlabel("glayer")
plt.ylabel("z")
plt.show()

# 1:1
plt.scatter(csv_train["hit1_q"],csv_train["hit1_dE_amp"]) # -3 to 3, even distrib
plt.title("dE_amp vs q")
plt.xlabel("q")
plt.ylabel("dE_amp")
plt.show()

# %%
aax = 
plt.plot()

# %% [markdown]
# # Depricated?

# %% [markdown]
# ## Non Custom Loss

# %%
# --==Not in use?==--
# lr_schedule = keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=1e-3,
#     decay_steps=10000,
#     decay_rate=0.8)

from keras.layers import Dense

nInput = 10

# inputs = keras.layers.Input((None,nInput))
# print("train shape of one batch:", x_train.shape[1:])

# --==Set seed to get identical results==-- begin
# from tensorflow.random import set_seed
# np.random.seed(1)
# set_seed(2)
# --==Set seed to get identical results==-- end


#--==Set Weights==--
# loss_weights = [1/(sd**2)]
# loss_weights = np.array(loss_weights)/sum(loss_weights)
# model.compile(optimizer=optimizer, loss="mse", loss_weights=loss_weights, metrics=["mae"])

inputs = keras.Input((None,nInput),ragged=True)

# --==Choose model==--
# x = model(inputs)
# x = model_timeless(inputs)
# x = RNNTime(inputs)
x = RNNTimeless(inputs)
# x = RNNTimeStateful(inputs)


outs = {
    "q_pt":Dense(1, name="q_pt")(x),
    "phi":Dense(1, name="phi")(x),
    "tanl":Dense(1, name="tanl")(x),
    "D":Dense(1, name="D")(x),
    "z":Dense(1, name="z")(x)
}

y_dict = {
    "q_pt":y_train[:,0],
    "phi":y_train[:,1],
    "tanl":y_train[:,2],
    "D":y_train[:,3],
    "z":y_train[:,4]
}


# model = keras.Model(inputs=inputs, outputs=x, name="RNNModel")
# model = keras.Model(inputs=inputs, outputs=x, name="RNNModel")
model = keras.Model(inputs=inputs, outputs=outs, name="RNNModel")

model.compile(optimizer="adam", loss="mse", metrics=["mae"])

model.summary()

# %%
es = keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.01, patience=50, mode='min', verbose=1, restore_best_weights=True)
rag_x = x_train[0]
H = model.fit(x=rag_x, y=y_dict, batch_size=64, epochs=100, verbose=1, callbacks=[es])

# Overfit
# es = keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.001, patience=100, mode='min', verbose=1, restore_best_weights=True)
# H = model.fit(x=x_train[:10], y=y_train[:10], batch_size=1, epochs=200, verbose=1, shuffle=True, callbacks=[es])

# %% [markdown]
# ## Versions

# %% [markdown]
# ### V2

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
#--------------------------------------------
# Define custom loss function 
def customLoss(y_true, y_pred, invcov):
  # print(type(y_true))    #<class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>


  # print(y_pred)

  y_pred_a = []
  for k in y_pred.keys():
    y_pred_a.append(np.squeeze(y_pred[k]))

  y_pred = np.array(y_pred_a).astype("float64")
  y_pred = tf.transpose(y_pred, perm=(1,0))
  # print(y_pred.shape)
  print(y_pred)

  batch_size = tf.shape(y_pred)[0]
  print('y_pred shape: ' + str(y_pred.shape) )  # y_pred dict shape of each is (batch, 1)
  print('y_true shape: ' + str(y_true.shape) )  # y_true shape is (batch, 5)
  print('invcov shape: ' + str(invcov.shape) )  # invcov shape is (batch, 25)
  
  y_pred = K.reshape(y_pred, (batch_size, 5,1)) # y_pred  shape is now (batch, 5,1)
  y_true = K.reshape(y_true, (batch_size, 5,1)) # y_state shape is now (batch, 5,1)
  invcov = K.reshape(invcov, (batch_size, 5,5)) # invcov  shape is now (batch, 5,5)
  
  # n.b. we must use tf.transpose here an not K.transpose since the latter does not allow perm argument
  invcov = tf.transpose(invcov, perm=[0,2,1])     # invcov shape is now (batch, 5,5)
  
  # Difference between prediction and true state vectors
  y_diff = y_pred - y_true

  # n.b. use "batch_dot" and not "dot"!
  y_dot = K.batch_dot(invcov, y_diff)           # y_dot shape is (batch,5,1)
  y_loss = K.reshape(y_dot, (batch_size, 5))  # y_dot shape is now (batch,5)

  y_dict = {
      "q_pt":y_loss[:,0],
      "phi":y_loss[:,1],
      "tanl":y_loss[:,2],
      "D":y_loss[:,3],
      "z":y_loss[:,4],
  }

  # y_dot = K.reshape(y_dot, (batch_size, 1, 5))  # y_dot shape is now (batch,1,5)
  # y_loss = K.batch_dot(y_dot, y_diff)           # y_loss shape is (batch,1,1)
  # y_loss = K.reshape(y_loss, (batch_size,))     # y_loss shape is now (batch)
  return y_dict
#--------------------------------------------
# Test loss function
# x_test = y_train[0]
x_test = x_train[2][0:4]
y_test = model.predict([x_train[0][0:4],x_train[1][0:4],x_train[2][0:4]])
inconv_test = x_train[1][0:4]

# for k in y_test.keys():
#   y_test[k] = np.squeeze(y_test[k])
# print(y_test)

# print(y_test)
# y_test_a = []
# for k in y_test.keys():
#   y_test_a.append(y_test[k])
# y_test = np.squeeze(np.array(y_test_a))
# print(y_test.shape)
# print(y_test)

# loss = K.eval(customLoss(K.variable([x_test,x_test,x_test]), K.variable([y_test,y_test,y_test]), K.variable([inconv_test,inconv_test,inconv_test])))
loss = K.eval(customLoss(x_test, y_test, inconv_test))
# print('loss shape: '    + str(loss.shape)    )
print(loss)

# %% [markdown]
# ### V3

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
#--------------------------------------------
# Define custom loss function 
def customLoss(q_pt_true, phi_true, tanl_true, D_true, z_true, q_pt_pred, phi_pred, tanl_pred, D_pred, z_pred, invcov):


  y_pred = [q_pt_pred, phi_pred, tanl_pred, D_pred, z_pred]
  # y_pred = np.array(y_pred).astype("float64")
  y_pred = tf.transpose(y_pred, perm=(1,0))
  y_pred = tf.cast(y_pred, "float64")

  y_true = [q_pt_true, phi_true, tanl_true, D_true, z_true]
  # y_true = np.array(y_true).astype("float64")
  y_true = tf.transpose(y_true, perm=(1,0))
  y_true = tf.cast(y_true, "float64")

  batch_size = tf.shape(y_pred)[0]
  print('y_pred shape: ' + str(y_pred.shape) )  # y_pred dict shape of each is (batch, 1)
  print('y_true shape: ' + str(y_true.shape) )  # y_true shape is (batch, 5)
  print('invcov shape: ' + str(invcov.shape) )  # invcov shape is (batch, 25)
  
  y_pred = K.reshape(y_pred, (batch_size, 5,1)) # y_pred  shape is now (batch, 5,1)
  y_true = K.reshape(y_true, (batch_size, 5,1)) # y_state shape is now (batch, 5,1)
  invcov = K.reshape(invcov, (batch_size, 5,5)) # invcov  shape is now (batch, 5,5)
  
  # n.b. we must use tf.transpose here an not K.transpose since the latter does not allow perm argument
  invcov = tf.transpose(invcov, perm=[0,2,1])     # invcov shape is now (batch, 5,5)
  
  # Difference between prediction and true state vectors
  y_diff = y_pred - y_true

  # n.b. use "batch_dot" and not "dot"!
  y_dot = K.batch_dot(invcov, y_diff)           # y_dot shape is (batch,5,1)
  y_loss = K.reshape(y_dot, (batch_size, 5))  # y_dot shape is now (batch,5)

  y_dict = {
      "q_pt":y_loss[:,0],
      "phi":y_loss[:,1],
      "tanl":y_loss[:,2],
      "D":y_loss[:,3],
      "z":y_loss[:,4],
  }

  # y_dot = K.reshape(y_dot, (batch_size, 1, 5))  # y_dot shape is now (batch,1,5)
  # y_loss = K.batch_dot(y_dot, y_diff)           # y_loss shape is (batch,1,1)
  # y_loss = K.reshape(y_loss, (batch_size,))     # y_loss shape is now (batch)
  return y_dict
#--------------------------------------------
# Test loss function
# x_test = y_train[0]
x_test = x_train[2][0:4]
y_test = model.predict([x_train[0][0:4],x_train[1][0:4],x_train[2][0:4]])
inconv_test = x_train[1][0:4]

y_test_a = []
for k in y_test.keys():
  y_test_a.append(y_test[k])
y_test = np.squeeze(np.array(y_test_a))
y_test = np.swapaxes(y_test, 0, 1)
print(y_test.shape)


# loss = K.eval(customLoss(K.variable([x_test,x_test,x_test]), K.variable([y_test,y_test,y_test]), K.variable([inconv_test,inconv_test,inconv_test])))
loss = K.eval(customLoss(x_test[:,0],x_test[:,1],x_test[:,2],x_test[:,3],x_test[:,4], y_test[:,0], y_test[:,1],y_test[:,2],y_test[:,3],y_test[:,4], inconv_test))
# print('loss shape: '    + str(loss.shape)    )
print(loss)

# %% [markdown]
# ### V4

# %% [markdown]
# So, we have the prediction and true vector
#
# $$
# y_{pred}=
# \begin{bmatrix}
# q\_pt \\ phi \\ tanl \\ D \\ z
# \end{bmatrix}
# $$
#
# We have the inverse covariance matrix, we'll label it $C^{-1}$:
#
# and $y_p = y_{predict}$
#
# $$
# C^{-1} =
# \begin{bmatrix}
# qq & qp & qt & qd & qz \\
# qp & pp & pt & pd & pz \\
# qt & pt & tt & td & tz \\
# qd & pd & td & dd & dz \\
# qz & pz & tz & dz & zz \\
# \end{bmatrix}
# $$
#
# Thus, the formula before was:
#
# $$
# loss = C^{-1} \cdot \vec{y_p}  \cdot \vec{y_p}
# $$
#
# $$
#   y_{dot} =
#   \begin{bmatrix}
#     qq & qp & qt & qd & qz \\
#     qp & pp & pt & pd & pz \\
#     qt & pt & tt & td & tz \\
#     qd & pd & td & dd & dz \\
#     qz & pz & tz & dz & zz
#   \end{bmatrix}
#   \cdot
#   \begin{bmatrix}
#     q\_pt \\ phi \\ tanl \\ D \\ z
#   \end{bmatrix}
# $$
#
# $$
#   y_{dot} =
#   \begin{bmatrix}
#     qq*q\_pt + qp*phi + qt*tanl + qd*D + qz*z \\
#     qp*q\_pt + pp*phi + pt*tanl + pd*D + pz*z \\
#     qt*q\_pt + pt*phi + tt*tanl + td*D + tz*z \\
#     qd*q\_pt + pd*phi + td*tanl + dd*D + dz*z \\
#     qz*q\_pt + dz*phi + tz*tanl + pz*D + zz*z
#   \end{bmatrix}
# $$
#
# ---
#
# Now, working on the output split for each variable, im looking for ways to seperate the variables after that operation.
# So maybe just sum the q_pt column of the matrix and multiply by q_pt?
#
# Maybe this would work? :
#
# $$
# loss_{q\_pt} =  y_p^{q\_pt} * \sum_{i=0}^{4} C^{-1}_{qi}
# $$
#
# Where $C^{-1}_q$ is one row or column of the matrix of that variable

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
#--------------------------------------------
# Define custom loss function 
def customLoss(y_true, y_pred, invcov):
  # print(type(y_true))    #<class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>

  # print(y_pred)

  # Theoretically:
  # K.dot(invcov[0,:] * q_pt,q_pt)    # ?
  


  y_pred_a = []
  for k in y_pred.keys():
    y_pred_a.append(np.squeeze(y_pred[k]))

  y_pred = np.array(y_pred_a).astype("float64")
  y_pred = tf.transpose(y_pred, perm=(1,0))
  # print(y_pred.shape)
  print(y_pred)

  batch_size = tf.shape(y_pred)[0]
  print('y_pred shape: ' + str(y_pred.shape) )  # y_pred dict shape of each is (batch, 1)
  print('y_true shape: ' + str(y_true.shape) )  # y_true shape is (batch, 5)
  print('invcov shape: ' + str(invcov.shape) )  # invcov shape is (batch, 25)
  
  y_pred = K.reshape(y_pred, (batch_size, 5,1)) # y_pred  shape is now (batch, 5,1)
  y_true = K.reshape(y_true, (batch_size, 5,1)) # y_state shape is now (batch, 5,1)
  invcov = K.reshape(invcov, (batch_size, 5,5)) # invcov  shape is now (batch, 5,5)
  
  # n.b. we must use tf.transpose here an not K.transpose since the latter does not allow perm argument
  invcov = tf.transpose(invcov, perm=[0,2,1])     # invcov shape is now (batch, 5,5)
  
  # Difference between prediction and true state vectors
  y_diff = y_pred - y_true

  # n.b. use "batch_dot" and not "dot"!
  y_dot = K.batch_dot(invcov, y_diff)           # y_dot shape is (batch,5,1)
  y_loss = K.reshape(y_dot, (batch_size, 5))  # y_dot shape is now (batch,5)

  y_dict = {
      "q_pt":y_loss[:,0],
      "phi":y_loss[:,1],
      "tanl":y_loss[:,2],
      "D":y_loss[:,3],
      "z":y_loss[:,4],
  }

  # y_dot = K.reshape(y_dot, (batch_size, 1, 5))  # y_dot shape is now (batch,1,5)
  # y_loss = K.batch_dot(y_dot, y_diff)           # y_loss shape is (batch,1,1)
  # y_loss = K.reshape(y_loss, (batch_size,))     # y_loss shape is now (batch)
  return y_dict
#--------------------------------------------
# Test loss function
# x_test = y_train[0]
x_test = x_train[2][0:4]
y_test = model.predict([x_train[0][0:4],x_train[1][0:4],x_train[2][0:4]])
inconv_test = x_train[1][0:4]

# for k in y_test.keys():
#   y_test[k] = np.squeeze(y_test[k])
# print(y_test)

# print(y_test)
# y_test_a = []
# for k in y_test.keys():
#   y_test_a.append(y_test[k])
# y_test = np.squeeze(np.array(y_test_a))
# print(y_test.shape)
# print(y_test)

# loss = K.eval(customLoss(K.variable([x_test,x_test,x_test]), K.variable([y_test,y_test,y_test]), K.variable([inconv_test,inconv_test,inconv_test])))
loss = K.eval(customLoss(x_test, y_test, inconv_test))
# print('loss shape: '    + str(loss.shape)    )
print(loss)

# %% [markdown]
# ### V5 unedited

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
#--------------------------------------------
# Define custom loss function 
def customLoss(y_true, y_pred, invcov):
  # print(type(y_true))    #<class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>

  batch_size = tf.shape(y_pred)[0]
  print('y_pred shape: ' + str(y_pred.shape) )  # y_pred shape is (batch, 5)
  print('y_true shape: ' + str(y_true.shape) )  # y_true shape is (batch, 5)
  print('invcov shape: ' + str(invcov.shape) )  # invcov shape is (batch, 25)
  
  y_pred = K.reshape(y_pred, (batch_size, 5,1)) # y_pred  shape is now (batch, 5,1)
  y_true = K.reshape(y_true, (batch_size, 5,1)) # y_state shape is now (batch, 5,1)
  invcov = K.reshape(invcov, (batch_size, 5,5)) # invcov  shape is now (batch, 5,5)
  
  # n.b. we must use tf.transpose here an not K.transpose since the latter does not allow perm argument
  invcov = tf.transpose(invcov, perm=[0,2,1])     # invcov shape is now (batch, 5,5)
  
  # Difference between prediction and true state vectors
  y_diff = y_pred - y_true

  # n.b. use "batch_dot" and not "dot"!
  y_dot = K.batch_dot(invcov, y_diff)           # y_dot shape is (batch,5,1)
  y_dot = K.reshape(y_dot, (batch_size, 1, 5))  # y_dot shape is now (batch,1,5)
  y_loss = K.batch_dot(y_dot, y_diff)           # y_loss shape is (batch,1,1)
  y_loss = K.reshape(y_loss, (batch_size,))     # y_loss shape is now (batch)
  # y_dict = {
  #     "q_pt":y_diff[0]*y_diff[0],
  #     "phi":y_diff[0]*y_diff[0]
  # }
  # y_diff[0] / invcov[0][0]
  return y_loss

#--------------------------------------------
# Test loss function
# x_test = x_train[2][0]
# y_test = model.predict([x_train[0][0:1],x_train[1][0:1],x_train[2][0:1]])
# y_test = np.squeeze(y_test)
# inconv_test = x_train[1][0]

# loss = K.eval(customLoss(K.variable([x_test,x_test,x_test]), K.variable([y_test,y_test,y_test]), K.variable([inconv_test,inconv_test,inconv_test])))
# # print('loss shape: '    + str(loss.shape)    )
# print(loss)

# %% [markdown]
# ### V6 New Way

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
def customLoss(m_invcov):
  def customLoss_fn(y_true, y_pred):
    batch_size = tf.shape(y_pred)[0]

    y_pred = tf.cast(K.reshape(y_pred, (batch_size, 5,1)),"float64") # y_pred  shape is now (batch, 5,1)
    y_true = tf.cast(K.reshape(y_true, (batch_size, 5,1)),"float64") # y_state shape is now (batch, 5,1)
    invcov = tf.cast(K.reshape(m_invcov, (batch_size, 5,5)),"float64") # invcov  shape is now (batch, 5,5)
    
    # n.b. we must use tf.transpose here an not K.transpose since the latter does not allow perm argument
    invcov = tf.transpose(invcov, perm=[0,2,1])     # invcov shape is now (batch, 5,5)
    
    # Difference between prediction and true state vectors
    y_diff = y_pred - y_true

    # n.b. use "batch_dot" and not "dot"!
    y_dot = K.batch_dot(invcov, y_diff)           # y_dot shape is (batch,5,1)
    y_dot = K.reshape(y_dot, (batch_size, 1, 5))  # y_dot shape is now (batch,1,5)
    y_loss = K.batch_dot(y_dot, y_diff)           # y_loss shape is (batch,1,1)
    y_loss = K.reshape(y_loss, (batch_size,))     # y_loss shape is now (batch)
    return y_loss
  return customLoss_fn

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
def customLoss(y_true, y_pred, invcov):
  batch_size = tf.shape(y_pred)[0]

  print('y_pred shape: ' + str(y_pred.shape) )  # y_pred shape is (batch, 5)
  print('y_true shape: ' + str(y_true.shape) )  # y_true shape is (batch, 5)
  print('invcov shape: ' + str(invcov.shape) )  # invcov shape is (batch, 25)

  y_pred = tf.cast(K.reshape(y_pred, (batch_size, 5,1)),"float64") # y_pred  shape is now (batch, 5,1)
  y_true = tf.cast(K.reshape(y_true, (batch_size, 5,1)),"float64") # y_state shape is now (batch, 5,1)
  invcov = tf.cast(K.reshape(invcov, (batch_size, 5,5)),"float64") # invcov  shape is now (batch, 5,5)
  
  # n.b. we must use tf.transpose here an not K.transpose since the latter does not allow perm argument
  invcov = tf.transpose(invcov, perm=[0,2,1])     # invcov shape is now (batch, 5,5)
  
  # Difference between prediction and true state vectors
  y_diff = y_pred - y_true

  # n.b. use "batch_dot" and not "dot"!
  y_dot = K.batch_dot(invcov, y_diff)           # y_dot shape is (batch,5,1)
  y_dot = K.reshape(y_dot, (batch_size, 1, 5))  # y_dot shape is now (batch,1,5)
  y_loss = K.batch_dot(y_dot, y_diff)           # y_loss shape is (batch,1,1)
  y_loss = K.reshape(y_loss, (batch_size,))     # y_loss shape is now (batch)
  return y_loss
